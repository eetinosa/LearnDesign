# %%
#import libraries
import requests
import re
from bs4 import BeautifulSoup
from requests import get
url = "https://hackr.io/tutorials/learn-figma"
response = get(url)
#We’ll now create a BeautifulSoup object, or a parse tree. This object takes as its arguments the page.text document from Requests (the content of the server’s response) and then parses it from Python’s built-in html.parser.
soup = BeautifulSoup(response.text, 'html.parser')

# Pull all text from the tuturial divison that contains course listing
courses = soup.find_all('div', class_ ="tut-list tut-list-new tut-row")
print(type(courses))
print(len(courses))
# Out:
# <class 'bs4.element.ResultSet'>
# 7

# %% [markdown]
# Now we’ll select each container, and extract, by turn, each item of interest:
#
# - Course title
# - Votes
# - Author
# - Links (Course, Author, Hackr)
# - Course Features: (Free / Paid) (video / book ) (Beginner / Intermediate / Advanced)

# %%
# Lists to store the scraped data in
CourseTitles = []
Votes = []
CourseLink = []
AuthorName = []
AuthorLink = []
HackrLink = []
CourseCost = []
CourseType = []
StudentType = []


    
for course in courses:
    CourseTitle = course.div.find('span', class_ = 'tutorial-title-txt').text.strip()
    CourseTitles.append(CourseTitle)


    NoOfVote  = course.div.find('span', class_ = 'count').text.strip()
    Votes.append(NoOfVote)

    Link1 = course.find("div", class_="title-links no-margin").find('a')["href"]
    CourseLink.append(Link1)
    
    Name = course.find("a", class_="author no-marginright paddingleft-xs").text.strip()
    AuthorName.append(Name)
    
    Link2  = course.find("div", class_="action author").find('a')["href"]
    AuthorLink.append(Link2)
    
    Link3 = course.find("a", attrs={'href': re.compile("https://hackr.io/tutorial/")}).get("href") 
    HackrLink.append(Link3)
        
    features  = course.find_all('div', class_ = "tut-label-group marginright-sm")
    for future in features:
        x=future.text.split()
    feat1 = x[0]
    if len(x) > 2:
        feat2 = x[1]
        feat3 = x[2]
    elif x[1] == ("Beginner" or "Advanced"):
        feat2 =None
        feat3= x[1]
    else:
        feat2 = x[1]
        feat3 = None
    CourseCost.append(feat1)
    CourseType.append(feat2)
    StudentType.append(feat3)
        

print (f"Courses : {CourseTitles}\n")
print (f"Votes : {Votes}\n")
print (f"CourseLink : {CourseLink}\n")
print (f"Author : {AuthorName}\n")
print (f"AuthorLink : {AuthorLink}\n")
print (f"HackrLink : {HackrLink}\n")
print (f"CourseLink : {CourseLink}\n")
print (f"CourseCost : {CourseCost}\n")
print (f"CourseType : {CourseType}\n")
print (f"StudentType : {StudentType}\n")
# Out:
# Courses : ['Figma Tutorials', 'Figma Course', 'Figma 101', 'Figma Tips and Tricks', 'Design System in  Figma', 'Figma For Beginners', 'Getting Started - Figma end-to-end']
#
# Votes : ['21', '5', '4', '2', '2', '2', '1']
#
# CourseLink : ['https://www.youtube.com/watch?v=RFi7wQHUP0c&list=PLXDU_eVOJTx4HJKh8tQkQRtIe5YlP5smB', 'https://learnux.io/course/figma', 'https://trydesignlab.com/figma-101-course/lessons', 'https://webdesign.tutsplus.com/series/figma-tips-and-tricks--cms-1299', 'https://designcode.io/design-system-figma', 'http://figmaforbeginners.com', 'https://www.youtube.com/watch?v=T0kRCTOX0zY']
#
# Author : ['Jack', 'Daniel', 'Ashish', 'Ian', 'Ashish', 'Daniel', 'Chris']
#
# AuthorLink : ['https://hackr.io/jack-avery-1', 'https://hackr.io/daniel-lee', 'https://hackr.io/ashish-bogawat', 'https://hackr.io/ian-yates', 'https://hackr.io/ashish-bogawat', 'https://hackr.io/daniel-pendergast', 'https://hackr.io/chris-duarte']
#
# HackrLink : ['https://hackr.io/tutorial/figma-tutorials', 'https://hackr.io/tutorial/figma-course', 'https://hackr.io/tutorial/figma-101', 'https://hackr.io/tutorial/figma-tips-and-tricks', 'https://hackr.io/tutorial/design-system-in-figma', 'https://hackr.io/tutorial/figma-for-beginners', 'https://hackr.io/tutorial/getting-started-figma-end-to-end']
#
# CourseLink : ['https://www.youtube.com/watch?v=RFi7wQHUP0c&list=PLXDU_eVOJTx4HJKh8tQkQRtIe5YlP5smB', 'https://learnux.io/course/figma', 'https://trydesignlab.com/figma-101-course/lessons', 'https://webdesign.tutsplus.com/series/figma-tips-and-tricks--cms-1299', 'https://designcode.io/design-system-figma', 'http://figmaforbeginners.com', 'https://www.youtube.com/watch?v=T0kRCTOX0zY']
#
# CourseCost : ['Free', 'Free', 'Free', 'Free', 'Free', 'Free', 'Free']
#
# CourseType : ['Video', 'Video', None, None, None, None, None]
#
# StudentType : ['Beginner', 'Beginner', 'Beginner', 'Beginner', 'Beginner', 'Beginner', 'Beginner']

# %%
import pandas as pd
FigmaCourses = pd.DataFrame({'Course': CourseTitles,
'Votes': Votes,
"Course Link":CourseLink,
"Author ":AuthorName,
"Author Link":AuthorLink,
"Hackr Link":HackrLink,
"Course Cost":CourseCost,
"Course Type":CourseType,
"Course Cost":CourseCost,
"Student Type":StudentType
})
print(FigmaCourses.info())
FigmaCourses
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Course        7 non-null      object
#  1   Votes         7 non-null      object
#  2   Course Link   7 non-null      object
#  3   Author        7 non-null      object
#  4   Author Link   7 non-null      object
#  5   Hackr Link    7 non-null      object
#  6   Course Cost   7 non-null      object
#  7   Course Type   2 non-null      object
#  8   Student Type  7 non-null      object
# dtypes: object(9)
# memory usage: 632.0+ bytes
# None
#                                Course Votes  \
# 0                     Figma Tutorials    21
# 1                        Figma Course     5
# 2                           Figma 101     4
# 3               Figma Tips and Tricks     2
# 4             Design System in  Figma     2
# 5                 Figma For Beginners     2
# 6  Getting Started - Figma end-to-end     1
#
#                                          Course Link Author   \
# 0  https://www.youtube.com/watch?v=RFi7wQHUP0c&li...    Jack
# 1                    https://learnux.io/course/figma  Daniel
# 2  https://trydesignlab.com/figma-101-course/lessons  Ashish
# 3  https://webdesign.tutsplus.com/series/figma-ti...     Ian
# 4          https://designcode.io/design-system-figma  Ashish
# 5                       http://figmaforbeginners.com  Daniel
# 6        https://www.youtube.com/watch?v=T0kRCTOX0zY   Chris
#
#                           Author Link  \
# 0       https://hackr.io/jack-avery-1
# 1         https://hackr.io/daniel-lee
# 2     https://hackr.io/ashish-bogawat
# 3          https://hackr.io/ian-yates
# 4     https://hackr.io/ashish-bogawat
# 5  https://hackr.io/daniel-pendergast
# 6       https://hackr.io/chris-duarte
#
#                                           Hackr Link Course Cost Course Type  \
# 0          https://hackr.io/tutorial/figma-tutorials        Free       Video
# 1             https://hackr.io/tutorial/figma-course        Free       Video
# 2                https://hackr.io/tutorial/figma-101        Free        None
# 3    https://hackr.io/tutorial/figma-tips-and-tricks        Free        None
# 4   https://hackr.io/tutorial/design-system-in-figma        Free        None
# 5      https://hackr.io/tutorial/figma-for-beginners        Free        None
# 6  https://hackr.io/tutorial/getting-started-figm...        Free        None
#
#   Student Type
# 0     Beginner
# 1     Beginner
# 2     Beginner
# 3     Beginner
# 4     Beginner
# 5     Beginner
# 6     Beginner

# %%
FigmaCourses.to_csv('FigmaCourses.csv')
