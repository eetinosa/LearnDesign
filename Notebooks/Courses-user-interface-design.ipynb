# %%
#import libraries
import requests
import re
from bs4 import BeautifulSoup
from requests import get
url = "https://hackr.io/tutorials/learn-user-interface-design"
response = get(url)
#We’ll now create a BeautifulSoup object, or a parse tree. This object takes as its arguments the page.text document from Requests (the content of the server’s response) and then parses it from Python’s built-in html.parser.
soup = BeautifulSoup(response.text, 'html.parser')

# Pull all text from the tuturial divison that contains course listing
courses = soup.find_all('div', class_ ="tut-list tut-list-new tut-row")
print(type(courses))
print(len(courses))
# Out:
# <class 'bs4.element.ResultSet'>
# 11

# %% [markdown]
# Now we’ll select each container, and extract, by turn, each item of interest:
#
# - Course title
# - Votes
# - Author
# - Links (Course, Author, Hackr)
# - Course Features: (Free / Paid) (video / book ) (Beginner / Intermediate / Advanced)

# %%
# Lists to store the scraped data in
CourseTitles = []
Votes = []
CourseLink = []
AuthorName = []
AuthorLink = []
HackrLink = []
CourseCost = []
CourseType = []
StudentType = []


    
for course in courses:
    CourseTitle = course.div.find('span', class_ = 'tutorial-title-txt').text.strip()
    CourseTitles.append(CourseTitle)


    NoOfVote  = course.div.find('span', class_ = 'count').text.strip()
    Votes.append(NoOfVote)

    Link1 = course.find("div", class_="title-links no-margin").find('a')["href"]
    CourseLink.append(Link1)
    
    Name = course.find("a", class_="author no-marginright paddingleft-xs").text.strip()
    AuthorName.append(Name)
    
    Link2  = course.find("div", class_="action author").find('a')["href"]
    AuthorLink.append(Link2)
    
    Link3 = course.find("a", attrs={'href': re.compile("https://hackr.io/tutorial/")}).get("href") 
    HackrLink.append(Link3)
        
    features  = course.find_all('div', class_ = "tut-label-group marginright-sm")
    for future in features:
        x=future.text.split()
    feat1 = x[0]
    if len(x) > 2:
        feat2 = x[1]
        feat3 = x[2]
    elif x[1] == ("Beginner" or "Advanced"):
        feat2 =None
        feat3= x[1]
    else:
        feat2 = x[1]
        feat3 = None
    CourseCost.append(feat1)
    CourseType.append(feat2)
    StudentType.append(feat3)
        

print (f"Courses : {CourseTitles}\n")
print (f"Votes : {Votes}\n")
print (f"CourseLink : {CourseLink}\n")
print (f"Author : {AuthorName}\n")
print (f"AuthorLink : {AuthorLink}\n")
print (f"HackrLink : {HackrLink}\n")
print (f"CourseLink : {CourseLink}\n")
print (f"CourseCost : {CourseCost}\n")
print (f"CourseType : {CourseType}\n")
print (f"StudentType : {StudentType}\n")
# Out:
# Courses : ['Create Pixel Perfect Work with UI Design', 'UI & Web-design for Beginners', 'Learn UI Design', 'Material Design', 'Design 101 Course by Design Lab', 'Introduction to Web Design and Development', 'Learn UI/UX Design with Abhinav', 'User Interface Design', 'The iOS Design Guidelines', 'Complete Web and Mobile Designer', 'Micro Frontends in Action']
#
# Votes : ['3', '19', '3', '3', '2', '1', '1', '1', '1', '+1', '+1']
#
# CourseLink : ['http://share.trydesignlab.com/hackrioui', 'https://www.youtube.com/watch?v=QJ9ygdD2sIY', 'http://learnui.design/', 'https://material.io/design/', 'http://share.trydesignlab.com/hackriodesign101', 'https://linkedin-learning.pxf.io/dAnkk', 'https://www.youtube.com/playlist?list=PLDtHAiqIa4wa5MBbE_XDoqY51sAkQnkjt', 'https://www.javatpoint.com/software-engineering-user-interface-design', 'https://ivomynttinen.com/blog/ios-design-guidelines', 'https://academy.zerotomastery.io/p/complete-web-and-mobile-designer', 'https://www.manning.com/books/micro-frontends-in-action?a_aid=hackrio']
#
# Author : ['Manuela', 'Jack', 'Jack', 'Himanshu', 'Jack', 'Swapnil', 'Biradar', 'Neha', 'Himanshu', 'Andrei', 'von']
#
# AuthorLink : ['https://hackr.io/manuela-odell', 'https://hackr.io/jack-avery-1', 'https://hackr.io/jack-avery-1', 'https://hackr.io/himanshu-vaishnav', 'https://hackr.io/jack-avery-1', 'https://hackr.io/swapnil-banga', 'https://hackr.io/-1092', 'https://hackr.io/nehapandey', 'https://hackr.io/himanshu-vaishnav', 'https://hackr.io/andreineagoie', 'https://hackr.io/von-latinski']
#
# HackrLink : ['https://hackr.io/tutorial/create-pixel-perfect-work-with-ui-design', 'https://hackr.io/tutorial/ui-web-design-for-beginners', 'https://hackr.io/tutorial/learn-ui-design', 'https://hackr.io/tutorial/material-design', 'https://hackr.io/tutorial/design-101-course-by-design-lab', 'https://hackr.io/tutorial/introduction-to-web-design-and-development', 'https://hackr.io/tutorial/learn-ui-ux-design-with-abhinav', 'https://hackr.io/tutorial/user-interface-design', 'https://hackr.io/tutorial/the-ios-design-guidelines', 'https://hackr.io/tutorial/complete-web-and-mobile-designer', 'https://hackr.io/tutorial/micro-frontends-in-action']
#
# CourseLink : ['http://share.trydesignlab.com/hackrioui', 'https://www.youtube.com/watch?v=QJ9ygdD2sIY', 'http://learnui.design/', 'https://material.io/design/', 'http://share.trydesignlab.com/hackriodesign101', 'https://linkedin-learning.pxf.io/dAnkk', 'https://www.youtube.com/playlist?list=PLDtHAiqIa4wa5MBbE_XDoqY51sAkQnkjt', 'https://www.javatpoint.com/software-engineering-user-interface-design', 'https://ivomynttinen.com/blog/ios-design-guidelines', 'https://academy.zerotomastery.io/p/complete-web-and-mobile-designer', 'https://www.manning.com/books/micro-frontends-in-action?a_aid=hackrio']
#
# CourseCost : ['Paid', 'Free', 'Paid', 'Free', 'Paid', 'Paid', 'Free', 'Free', 'Free', 'Paid', 'Paid']
#
# CourseType : ['Advanced', 'Video', 'Video', None, 'Video', 'Video', 'Video', 'Book', 'Beginner', 'Video', 'Book']
#
# StudentType : ['Certification', 'Beginner', 'Beginner', 'Beginner', 'Beginner', None, 'Beginner', 'Beginner', 'iOS', 'Beginner', 'Advanced']

# %%
import pandas as pd
UIDesignCourses = pd.DataFrame({'Course': CourseTitles,
'Votes': Votes,
"Course Link":CourseLink,
"Author ":AuthorName,
"Author Link":AuthorLink,
"Hackr Link":HackrLink,
"Course Cost":CourseCost,
"Course Type":CourseType,
"Course Cost":CourseCost,
"Student Type":StudentType
})
print(UIDesignCourses.info())
UIDesignCourses
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Course        11 non-null     object
#  1   Votes         11 non-null     object
#  2   Course Link   11 non-null     object
#  3   Author        11 non-null     object
#  4   Author Link   11 non-null     object
#  5   Hackr Link    11 non-null     object
#  6   Course Cost   11 non-null     object
#  7   Course Type   10 non-null     object
#  8   Student Type  10 non-null     object
# dtypes: object(9)
# memory usage: 920.0+ bytes
# None
#                                         Course Votes  \
# 0     Create Pixel Perfect Work with UI Design     3
# 1                UI & Web-design for Beginners    19
# 2                              Learn UI Design     3
# 3                              Material Design     3
# 4              Design 101 Course by Design Lab     2
# 5   Introduction to Web Design and Development     1
# 6              Learn UI/UX Design with Abhinav     1
# 7                        User Interface Design     1
# 8                    The iOS Design Guidelines     1
# 9             Complete Web and Mobile Designer    +1
# 10                   Micro Frontends in Action    +1
#
#                                           Course Link   Author   \
# 0             http://share.trydesignlab.com/hackrioui   Manuela
# 1         https://www.youtube.com/watch?v=QJ9ygdD2sIY      Jack
# 2                              http://learnui.design/      Jack
# 3                         https://material.io/design/  Himanshu
# 4      http://share.trydesignlab.com/hackriodesign101      Jack
# 5              https://linkedin-learning.pxf.io/dAnkk   Swapnil
# 6   https://www.youtube.com/playlist?list=PLDtHAiq...   Biradar
# 7   https://www.javatpoint.com/software-engineerin...      Neha
# 8   https://ivomynttinen.com/blog/ios-design-guide...  Himanshu
# 9   https://academy.zerotomastery.io/p/complete-we...    Andrei
# 10  https://www.manning.com/books/micro-frontends-...       von
#
#                            Author Link  \
# 0       https://hackr.io/manuela-odell
# 1        https://hackr.io/jack-avery-1
# 2        https://hackr.io/jack-avery-1
# 3   https://hackr.io/himanshu-vaishnav
# 4        https://hackr.io/jack-avery-1
# 5       https://hackr.io/swapnil-banga
# 6               https://hackr.io/-1092
# 7          https://hackr.io/nehapandey
# 8   https://hackr.io/himanshu-vaishnav
# 9       https://hackr.io/andreineagoie
# 10       https://hackr.io/von-latinski
#
#                                            Hackr Link Course Cost Course Type  \
# 0   https://hackr.io/tutorial/create-pixel-perfect...        Paid    Advanced
# 1   https://hackr.io/tutorial/ui-web-design-for-be...        Free       Video
# 2           https://hackr.io/tutorial/learn-ui-design        Paid       Video
# 3           https://hackr.io/tutorial/material-design        Free        None
# 4   https://hackr.io/tutorial/design-101-course-by...        Paid       Video
# 5   https://hackr.io/tutorial/introduction-to-web-...        Paid       Video
# 6   https://hackr.io/tutorial/learn-ui-ux-design-w...        Free       Video
# 7     https://hackr.io/tutorial/user-interface-design        Free        Book
# 8   https://hackr.io/tutorial/the-ios-design-guide...        Free    Beginner
# 9   https://hackr.io/tutorial/complete-web-and-mob...        Paid       Video
# 10  https://hackr.io/tutorial/micro-frontends-in-a...        Paid        Book
#
#      Student Type
# 0   Certification
# 1        Beginner
# 2        Beginner
# 3        Beginner
# 4        Beginner
# 5            None
# 6        Beginner
# 7        Beginner
# 8             iOS
# 9        Beginner
# 10       Advanced

# %%
UIDesignCourses.to_csv('UIDesignCourses.csv')
