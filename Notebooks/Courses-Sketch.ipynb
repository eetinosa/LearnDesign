# %%
#import libraries
import requests
import re
from bs4 import BeautifulSoup
from requests import get
url = "https://hackr.io/tutorials/learn-sketch"
response = get(url)
#We’ll now create a BeautifulSoup object, or a parse tree. This object takes as its arguments the page.text document from Requests (the content of the server’s response) and then parses it from Python’s built-in html.parser.
soup = BeautifulSoup(response.text, 'html.parser')

# Pull all text from the tuturial divison that contains course listing
courses = soup.find_all('div', class_ ="tut-list tut-list-new tut-row")
print(type(courses))
print(len(courses))
# Out:
# <class 'bs4.element.ResultSet'>
# 9

# %% [markdown]
# Now we’ll select each container, and extract, by turn, each item of interest:
#
# - Course title
# - Votes
# - Author
# - Links (Course, Author, Hackr)
# - Course Features: (Free / Paid) (video / book ) (Beginner / Intermediate / Advanced)

# %%
# Lists to store the scraped data in
CourseTitles = []
Votes = []
CourseLink = []
AuthorName = []
AuthorLink = []
HackrLink = []
CourseCost = []
CourseType = []
StudentType = []


    
for course in courses:
    CourseTitle = course.div.find('span', class_ = 'tutorial-title-txt').text.strip()
    CourseTitles.append(CourseTitle)


    NoOfVote  = course.div.find('span', class_ = 'count').text.strip()
    Votes.append(NoOfVote)

    Link1 = course.find("div", class_="title-links no-margin").find('a')["href"]
    CourseLink.append(Link1)
    
    Name = course.find("a", class_="author no-marginright paddingleft-xs")
    if Name is None:
        AuthorName.append(None)
    else:
        Names=Name.text.strip()
        AuthorName.append(Names)
    
    auth  = course.find("div", class_="action author").find('a')
    if auth is None:
        AuthorLink.append(None)
    else:
        Link2 = auth["href"]
        AuthorLink.append(Link2)
    
    hackr = course.find("a", attrs={'href': re.compile("https://hackr.io/tutorial/")}) 
    if hackr is None:
        HackrLink.append(None)
    else:
        Link3=hackr.get("href")
        HackrLink.append(Link3)
        
    features  = course.find_all('div', class_ = "tut-label-group marginright-sm")
    for future in features:
        x=future.text.split()
    feat1 = x[0]
    if len(x) > 2:
        feat2 = x[1]
        feat3 = x[2]
    elif x[1] == ("Beginner" or "Advanced"):
        feat2 =None
        feat3= x[1]
    else:
        feat2 = x[1]
        feat3 = None
    CourseCost.append(feat1)
    CourseType.append(feat2)
    StudentType.append(feat3)
        

print (f"Courses : {CourseTitles}\n")
print (f"Votes : {Votes}\n")
print (f"CourseLink : {CourseLink}\n")
print (f"Author : {AuthorName}\n")
print (f"AuthorLink : {AuthorLink}\n")
print (f"HackrLink : {HackrLink}\n")
print (f"CourseLink : {CourseLink}\n")
print (f"CourseCost : {CourseCost}\n")
print (f"CourseType : {CourseType}\n")
print (f"StudentType : {StudentType}\n")
# Out:
# Courses : ['Sketch 3 Tutorials', 'Sketch 101', 'Getting Started With Sketch', 'SketchCasts', 'Mastering Mobile App Design With Sketch 3', 'Mobile App Design In Sketch 3: UX and UI Design From Scratch', 'Sketch App Course', 'Sketch Tutorials', 'Sketch 3 from A to Z: Become an App Designer']
#
# Votes : ['12', '5', '5', '3', '2', '1', '+1', '+1', '+1']
#
# CourseLink : ['https://www.youtube.com/playlist?list=PLLnpHn493BHE6UIsdKYlS5zu-ZYvx22CS', 'https://trydesignlab.com/sketch-101-course', 'https://www.switchtosketchapp.com', 'https://www.sketchcasts.net/episodes/latest', 'https://click.linksynergy.com/deeplink?id=jU79Zysihs4&mid=39197&murl=https://www.udemy.com/sketch-design/', 'https://click.linksynergy.com/deeplink?id=jU79Zysihs4&mid=39197&murl=https://www.udemy.com/the-complete-design-course/', 'https://learnux.io/course/sketch', 'http://sketchmaster.com/', 'https://click.linksynergy.com/deeplink?id=jU79Zysihs4&mid=39197&murl=https://www.udemy.com/learnsketch3/']
#
# Author : ['Scott', 'Manuela', 'Rajat', 'Gaurav', 'Bharathi', 'Pinki', 'Learn', 'Bennett', 'Howard']
#
# AuthorLink : ['https://hackr.io/scott-tolinski', 'https://hackr.io/manuela-odell', 'https://hackr.io/rajat-patel-3', 'https://hackr.io/gaurav-gupta', 'https://hackr.io/bharathi-devarasu', 'https://hackr.io/pinki-pal', 'https://hackr.io/learn-ux', 'https://hackr.io/bennett-huffman', 'https://hackr.io/howard-galt']
#
# HackrLink : ['https://hackr.io/tutorial/sketch-3-tutorials', 'https://hackr.io/tutorial/sketch-101', 'https://hackr.io/tutorial/getting-started-with-sketch', 'https://hackr.io/tutorial/sketchcasts', 'https://hackr.io/tutorial/mastering-mobile-app-design-with-sketch-3', 'https://hackr.io/tutorial/mobile-app-design-in-sketch-3-ux-and-ui-design-from-scratch', 'https://hackr.io/tutorial/sketch-app-course', 'https://hackr.io/tutorial/sketch-tutorials', 'https://hackr.io/tutorial/sketch-3-from-a-to-z-become-an-app-designer']
#
# CourseLink : ['https://www.youtube.com/playlist?list=PLLnpHn493BHE6UIsdKYlS5zu-ZYvx22CS', 'https://trydesignlab.com/sketch-101-course', 'https://www.switchtosketchapp.com', 'https://www.sketchcasts.net/episodes/latest', 'https://click.linksynergy.com/deeplink?id=jU79Zysihs4&mid=39197&murl=https://www.udemy.com/sketch-design/', 'https://click.linksynergy.com/deeplink?id=jU79Zysihs4&mid=39197&murl=https://www.udemy.com/the-complete-design-course/', 'https://learnux.io/course/sketch', 'http://sketchmaster.com/', 'https://click.linksynergy.com/deeplink?id=jU79Zysihs4&mid=39197&murl=https://www.udemy.com/learnsketch3/']
#
# CourseCost : ['Free', 'Free', 'Free', 'Free', 'Paid', 'Paid', 'Paid', 'Paid', 'Paid']
#
# CourseType : ['Video', None, 'Beginner', 'Video', 'Video', 'Video', 'Video', 'Video', 'Video']
#
# StudentType : ['Sketch', 'Beginner', 'Video', None, 'Beginner', 'Beginner', 'Beginner', 'Beginner', 'Beginner']

# %%
import pandas as pd
SketchCourses = pd.DataFrame({'Course': CourseTitles,
'Votes': Votes,
"Course Link":CourseLink,
"Author ":AuthorName,
"Author Link":AuthorLink,
"Hackr Link":HackrLink,
"Course Cost":CourseCost,
"Course Type":CourseType,
"Course Cost":CourseCost,
"Student Type":StudentType
})
print(SketchCourses.info())
SketchCourses
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Course        9 non-null      object
#  1   Votes         9 non-null      object
#  2   Course Link   9 non-null      object
#  3   Author        9 non-null      object
#  4   Author Link   9 non-null      object
#  5   Hackr Link    9 non-null      object
#  6   Course Cost   9 non-null      object
#  7   Course Type   8 non-null      object
#  8   Student Type  8 non-null      object
# dtypes: object(9)
# memory usage: 776.0+ bytes
# None
#                                               Course Votes  \
# 0                                 Sketch 3 Tutorials    12
# 1                                         Sketch 101     5
# 2                        Getting Started With Sketch     5
# 3                                        SketchCasts     3
# 4          Mastering Mobile App Design With Sketch 3     2
# 5  Mobile App Design In Sketch 3: UX and UI Desig...     1
# 6                                  Sketch App Course    +1
# 7                                   Sketch Tutorials    +1
# 8       Sketch 3 from A to Z: Become an App Designer    +1
#
#                                          Course Link   Author   \
# 0  https://www.youtube.com/playlist?list=PLLnpHn4...     Scott
# 1         https://trydesignlab.com/sketch-101-course   Manuela
# 2                  https://www.switchtosketchapp.com     Rajat
# 3        https://www.sketchcasts.net/episodes/latest    Gaurav
# 4  https://click.linksynergy.com/deeplink?id=jU79...  Bharathi
# 5  https://click.linksynergy.com/deeplink?id=jU79...     Pinki
# 6                   https://learnux.io/course/sketch     Learn
# 7                           http://sketchmaster.com/   Bennett
# 8  https://click.linksynergy.com/deeplink?id=jU79...    Howard
#
#                           Author Link  \
# 0     https://hackr.io/scott-tolinski
# 1      https://hackr.io/manuela-odell
# 2      https://hackr.io/rajat-patel-3
# 3       https://hackr.io/gaurav-gupta
# 4  https://hackr.io/bharathi-devarasu
# 5          https://hackr.io/pinki-pal
# 6           https://hackr.io/learn-ux
# 7    https://hackr.io/bennett-huffman
# 8        https://hackr.io/howard-galt
#
#                                           Hackr Link Course Cost Course Type  \
# 0       https://hackr.io/tutorial/sketch-3-tutorials        Free       Video
# 1               https://hackr.io/tutorial/sketch-101        Free        None
# 2  https://hackr.io/tutorial/getting-started-with...        Free    Beginner
# 3              https://hackr.io/tutorial/sketchcasts        Free       Video
# 4  https://hackr.io/tutorial/mastering-mobile-app...        Paid       Video
# 5  https://hackr.io/tutorial/mobile-app-design-in...        Paid       Video
# 6        https://hackr.io/tutorial/sketch-app-course        Paid       Video
# 7         https://hackr.io/tutorial/sketch-tutorials        Paid       Video
# 8  https://hackr.io/tutorial/sketch-3-from-a-to-z...        Paid       Video
#
#   Student Type
# 0       Sketch
# 1     Beginner
# 2        Video
# 3         None
# 4     Beginner
# 5     Beginner
# 6     Beginner
# 7     Beginner
# 8     Beginner

# %%
SketchCourses.to_csv('SketchCourses.csv')
