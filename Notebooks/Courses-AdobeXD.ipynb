# %%
#import libraries
import requests
import re
from bs4 import BeautifulSoup
from requests import get
url = "https://hackr.io/tutorials/learn-adobe-experience-design"
response = get(url)
#We’ll now create a BeautifulSoup object, or a parse tree. This object takes as its arguments the page.text document from Requests (the content of the server’s response) and then parses it from Python’s built-in html.parser.
soup = BeautifulSoup(response.text, 'html.parser')

# Pull all text from the tuturial divison that contains course listing
courses = soup.find_all('div', class_ ="tut-list tut-list-new tut-row")
print(type(courses))
print(len(courses))
# Out:
# <class 'bs4.element.ResultSet'>
# 10

# %% [markdown]
# Now we’ll select each container, and extract, by turn, each item of interest:
#
# - Course title
# - Votes
# - Author
# - Links (Course, Author, Hackr)
# - Course Features: (Free / Paid) (video / book ) (Beginner / Intermediate / Advanced)

# %%
# Lists to store the scraped data in
CourseTitles = []
Votes = []
CourseLink = []
AuthorName = []
AuthorLink = []
HackrLink = []
CourseCost = []
CourseType = []
StudentType = []


    
for course in courses:
    CourseTitle = course.div.find('span', class_ = 'tutorial-title-txt').text.strip()
    CourseTitles.append(CourseTitle)


    NoOfVote  = course.div.find('span', class_ = 'count').text.strip()
    Votes.append(NoOfVote)

    Link1 = course.find("div", class_="title-links no-margin").find('a')["href"]
    CourseLink.append(Link1)
    
    Name = course.find("a", class_="author no-marginright paddingleft-xs")
    if Name is None:
        AuthorName.append(None)
    else:
        Names=Name.text.strip()
        AuthorName.append(Names)
    
    auth  = course.find("div", class_="action author").find('a')
    if auth is None:
        AuthorLink.append(None)
    else:
        Link2 = auth["href"]
        AuthorLink.append(Link2)
    
    hackr = course.find("a", attrs={'href': re.compile("https://hackr.io/tutorial/")}) 
    if hackr is None:
        HackrLink.append(None)
    else:
        Link3=hackr.get("href")
        HackrLink.append(Link3)
        
    features  = course.find_all('div', class_ = "tut-label-group marginright-sm")
    for future in features:
        x=future.text.split()
    feat1 = x[0]
    if len(x) > 2:
        feat2 = x[1]
        feat3 = x[2]
    elif x[1] == ("Beginner" or "Advanced"):
        feat2 =None
        feat3= x[1]
    else:
        feat2 = x[1]
        feat3 = None
    CourseCost.append(feat1)
    CourseType.append(feat2)
    StudentType.append(feat3)
        

print (f"Courses : {CourseTitles}\n")
print (f"Votes : {Votes}\n")
print (f"CourseLink : {CourseLink}\n")
print (f"Author : {AuthorName}\n")
print (f"AuthorLink : {AuthorLink}\n")
print (f"HackrLink : {HackrLink}\n")
print (f"CourseLink : {CourseLink}\n")
print (f"CourseCost : {CourseCost}\n")
print (f"CourseType : {CourseType}\n")
print (f"StudentType : {StudentType}\n")
# Out:
# Courses : ['Mastering Adobe XD', 'Designing & Prototyping an App in Adobe XD', 'How to Use Responsive Resize and Constraints in Adobe XD', 'Adobe Experience Design tutorials | Adobe', 'Adobe XD Course', 'UI/UX design with Adobe XD: Design & Prototype a Mobile App', 'Adobe Experience Design Tutorials', 'Adobe XD Prototyping', 'Adobe Experience Design CC', 'A Quick Start Guide to Adobe XD']
#
# Votes : ['4', '6', '4', '3', '2', '2', '1', '+1', '+1', '1']
#
# CourseLink : ['https://www.youtube.com/playlist?list=PLuQZzG-z6zBJvcSTgDleHPDyqRUXYkA6c', 'https://www.youtube.com/watch?v=mtZJUvzQrA4', 'https://webdesign.tutsplus.com/tutorials/how-to-use-responsive-resize-and-constraints-in-adobe-xd--cms-32019', 'https://helpx.adobe.com/experience-design/tutorials.html', 'https://learnux.io/course/adobe-xd', 'https://click.linksynergy.com/deeplink?id=jU79Zysihs4&mid=39197&murl=https://www.udemy.com/adobe-xd-course/', 'https://www.youtube.com/playlist?list=PLkiM1tZke4mivrZRPcqp_8oHFxlD8-IP5', 'https://www.youtube.com/playlist?list=PLuQZzG-z6zBIQNWikhYXU8rqhI6E7gGRv', 'https://www.youtube.com/playlist?list=PLJ4RelYJHoScuihpL_8-Om6UZIkhuW_zm', 'http://blog.graphicstock.com/graphic-design-tutorials/a-quick-start-guide-to-adobe-xd-8-essential-tutorials-for-experience-design-cc/']
#
# Author : ['David', None, 'Ian', 'Jack', 'Learn', 'Jack', 'Pawan', 'David', 'Tom', None]
#
# AuthorLink : ['https://hackr.io/davidfco1702', None, 'https://hackr.io/ian-yates', 'https://hackr.io/jack-avery-1', 'https://hackr.io/learn-ux', 'https://hackr.io/jack-avery-1', 'https://hackr.io/pawan-kumar-2', 'https://hackr.io/davidfco1702', 'https://hackr.io/tom-green', None]
#
# HackrLink : ['https://hackr.io/tutorial/mastering-adobe-xd', None, 'https://hackr.io/tutorial/how-to-use-responsive-resize-and-constraints-in-adobe-xd', 'https://hackr.io/tutorial/adobe-experience-design-tutorials-adobe', 'https://hackr.io/tutorial/adobe-xd-course', 'https://hackr.io/tutorial/uiux-design-with-adobe-xd-design-prototype-a-mobile-app', 'https://hackr.io/tutorial/adobe-experience-design-tutorials', 'https://hackr.io/tutorial/adobe-xd-prototyping', 'https://hackr.io/tutorial/adobe-experience-design-cc', None]
#
# CourseLink : ['https://www.youtube.com/playlist?list=PLuQZzG-z6zBJvcSTgDleHPDyqRUXYkA6c', 'https://www.youtube.com/watch?v=mtZJUvzQrA4', 'https://webdesign.tutsplus.com/tutorials/how-to-use-responsive-resize-and-constraints-in-adobe-xd--cms-32019', 'https://helpx.adobe.com/experience-design/tutorials.html', 'https://learnux.io/course/adobe-xd', 'https://click.linksynergy.com/deeplink?id=jU79Zysihs4&mid=39197&murl=https://www.udemy.com/adobe-xd-course/', 'https://www.youtube.com/playlist?list=PLkiM1tZke4mivrZRPcqp_8oHFxlD8-IP5', 'https://www.youtube.com/playlist?list=PLuQZzG-z6zBIQNWikhYXU8rqhI6E7gGRv', 'https://www.youtube.com/playlist?list=PLJ4RelYJHoScuihpL_8-Om6UZIkhuW_zm', 'http://blog.graphicstock.com/graphic-design-tutorials/a-quick-start-guide-to-adobe-xd-8-essential-tutorials-for-experience-design-cc/']
#
# CourseCost : ['Free', 'Free', 'Free', 'Free', 'Paid', 'Paid', 'Free', 'Free', 'Free', 'Free']
#
# CourseType : ['Video', 'Video', 'Video', 'Video', 'Video', 'Video', 'Video', 'Video', None, 'Video']
#
# StudentType : ['Advanced', 'Beginner', 'Beginner', 'Beginner', 'Beginner', 'Beginner', 'Beginner', 'Beginner', 'Beginner', 'Beginner']

# %%
import pandas as pd
AdobeXDCourses = pd.DataFrame({'Course': CourseTitles,
'Votes': Votes,
"Course Link":CourseLink,
"Author ":AuthorName,
"Author Link":AuthorLink,
"Hackr Link":HackrLink,
"Course Cost":CourseCost,
"Course Type":CourseType,
"Course Cost":CourseCost,
"Student Type":StudentType
})
print(AdobeXDCourses.info())
AdobeXDCourses
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Course        10 non-null     object
#  1   Votes         10 non-null     object
#  2   Course Link   10 non-null     object
#  3   Author        8 non-null      object
#  4   Author Link   8 non-null      object
#  5   Hackr Link    8 non-null      object
#  6   Course Cost   10 non-null     object
#  7   Course Type   9 non-null      object
#  8   Student Type  10 non-null     object
# dtypes: object(9)
# memory usage: 848.0+ bytes
# None
#                                               Course Votes  \
# 0                                 Mastering Adobe XD     4
# 1         Designing & Prototyping an App in Adobe XD     6
# 2  How to Use Responsive Resize and Constraints i...     4
# 3          Adobe Experience Design tutorials | Adobe     3
# 4                                    Adobe XD Course     2
# 5  UI/UX design with Adobe XD: Design & Prototype...     2
# 6                  Adobe Experience Design Tutorials     1
# 7                               Adobe XD Prototyping    +1
# 8                         Adobe Experience Design CC    +1
# 9                    A Quick Start Guide to Adobe XD     1
#
#                                          Course Link Author   \
# 0  https://www.youtube.com/playlist?list=PLuQZzG-...   David
# 1        https://www.youtube.com/watch?v=mtZJUvzQrA4    None
# 2  https://webdesign.tutsplus.com/tutorials/how-t...     Ian
# 3  https://helpx.adobe.com/experience-design/tuto...    Jack
# 4                 https://learnux.io/course/adobe-xd   Learn
# 5  https://click.linksynergy.com/deeplink?id=jU79...    Jack
# 6  https://www.youtube.com/playlist?list=PLkiM1tZ...   Pawan
# 7  https://www.youtube.com/playlist?list=PLuQZzG-...   David
# 8  https://www.youtube.com/playlist?list=PLJ4RelY...     Tom
# 9  http://blog.graphicstock.com/graphic-design-tu...    None
#
#                       Author Link  \
# 0   https://hackr.io/davidfco1702
# 1                            None
# 2      https://hackr.io/ian-yates
# 3   https://hackr.io/jack-avery-1
# 4       https://hackr.io/learn-ux
# 5   https://hackr.io/jack-avery-1
# 6  https://hackr.io/pawan-kumar-2
# 7   https://hackr.io/davidfco1702
# 8      https://hackr.io/tom-green
# 9                            None
#
#                                           Hackr Link Course Cost Course Type  \
# 0       https://hackr.io/tutorial/mastering-adobe-xd        Free       Video
# 1                                               None        Free       Video
# 2  https://hackr.io/tutorial/how-to-use-responsiv...        Free       Video
# 3  https://hackr.io/tutorial/adobe-experience-des...        Free       Video
# 4          https://hackr.io/tutorial/adobe-xd-course        Paid       Video
# 5  https://hackr.io/tutorial/uiux-design-with-ado...        Paid       Video
# 6  https://hackr.io/tutorial/adobe-experience-des...        Free       Video
# 7     https://hackr.io/tutorial/adobe-xd-prototyping        Free       Video
# 8  https://hackr.io/tutorial/adobe-experience-des...        Free        None
# 9                                               None        Free       Video
#
#   Student Type
# 0     Advanced
# 1     Beginner
# 2     Beginner
# 3     Beginner
# 4     Beginner
# 5     Beginner
# 6     Beginner
# 7     Beginner
# 8     Beginner
# 9     Beginner

# %%
AdobeXDCourses.to_csv('AdobeXDCourses.csv')
