# %%
#import libraries
import requests
import re
from bs4 import BeautifulSoup
from requests import get
url = "https://hackr.io/tutorials/learn-ux-research"
response = get(url)
#We’ll now create a BeautifulSoup object, or a parse tree. This object takes as its arguments the page.text document from Requests (the content of the server’s response) and then parses it from Python’s built-in html.parser.
soup = BeautifulSoup(response.text, 'html.parser')

# Pull all text from the tuturial divison that contains course listing
courses = soup.find_all('div', class_ ="tut-list tut-list-new tut-row")
print(type(courses))
print(len(courses))
# Out:
# <class 'bs4.element.ResultSet'>
# 7

# %% [markdown]
# Now we’ll select each container, and extract, by turn, each item of interest:
#
# - Course title
# - Votes
# - Author
# - Links (Course, Author, Hackr)
# - Course Features: (Free / Paid) (video / book ) (Beginner / Intermediate / Advanced)

# %%
# Lists to store the scraped data in
CourseTitles = []
Votes = []
CourseLink = []
AuthorName = []
AuthorLink = []
HackrLink = []
CourseCost = []
CourseType = []
StudentType = []


    
for course in courses:
    CourseTitle = course.div.find('span', class_ = 'tutorial-title-txt').text.strip()
    CourseTitles.append(CourseTitle)


    NoOfVote  = course.div.find('span', class_ = 'count').text.strip()
    Votes.append(NoOfVote)

    Link1 = course.find("div", class_="title-links no-margin").find('a')["href"]
    CourseLink.append(Link1)
    
    Name = course.find("a", class_="author no-marginright paddingleft-xs")
    if Name is None:
        AuthorName.append(None)
    else:
        Names=Name.text.strip()
        AuthorName.append(Names)
    
    auth  = course.find("div", class_="action author").find('a')
    if auth is None:
        AuthorLink.append(None)
    else:
        Link2 = auth["href"]
        AuthorLink.append(Link2)
    
    hackr = course.find("a", attrs={'href': re.compile("https://hackr.io/tutorial/")}) 
    if hackr is None:
        HackrLink.append(None)
    else:
        Link3=hackr.get("href")
        HackrLink.append(Link3)
        
    features  = course.find_all('div', class_ = "tut-label-group marginright-sm")
    for future in features:
        x=future.text.split()
    feat1 = x[0]
    if len(x) > 2:
        feat2 = x[1]
        feat3 = x[2]
    elif x[1] == ("Beginner" or "Advanced"):
        feat2 =None
        feat3= x[1]
    else:
        feat2 = x[1]
        feat3 = None
    CourseCost.append(feat1)
    CourseType.append(feat2)
    StudentType.append(feat3)
        

print (f"Courses : {CourseTitles}\n")
print (f"Votes : {Votes}\n")
print (f"CourseLink : {CourseLink}\n")
print (f"Author : {AuthorName}\n")
print (f"AuthorLink : {AuthorLink}\n")
print (f"HackrLink : {HackrLink}\n")
print (f"CourseLink : {CourseLink}\n")
print (f"CourseCost : {CourseCost}\n")
print (f"CourseType : {CourseType}\n")
print (f"StudentType : {StudentType}\n")
# Out:
# Courses : ['User Experience Research and Design Specialization', 'User Research: What It Is And Why You Should Do It', 'Learn User-Centered Design with UX Research & Strategy', 'User Research Mastery', 'The Practical Beginner’s Guide to User Research', 'How To Conduct User Experience Research Like A Professional', '7 Great, Tried and Tested UX Research Techniques']
#
# Votes : ['1', '2', '1', '+1', '+1', '+1', '+1']
#
# CourseLink : ['https://click.linksynergy.com/deeplink?id=jU79Zysihs4&mid=40328&murl=https://www.coursera.org/specializations/michiganux', 'https://www.interaction-design.org/literature/article/user-research-what-it-is-and-why-you-should-do-it', 'http://share.trydesignlab.com/hackriouxsc', 'http://courses.sarahdoody.com/p/user-research-mastery', 'https://www.uxpin.com/studio/blog/the-practical-beginners-guide-to-user-research/', 'https://careerfoundry.com/en/blog/ux-design/how-to-conduct-user-experience-research-like-a-professional/', 'https://www.interaction-design.org/literature/article/7-great-tried-and-tested-ux-research-techniques']
#
# Author : ['Saurabh', 'Rajat', 'Manuela', 'Saurabh', 'Jack', 'Jack', 'Jack']
#
# AuthorLink : ['https://hackr.io/saurabh-hooda', 'https://hackr.io/rajat-patel-3', 'https://hackr.io/manuela-odell', 'https://hackr.io/saurabh-hooda', 'https://hackr.io/jack-avery-1', 'https://hackr.io/jack-avery-1', 'https://hackr.io/jack-avery-1']
#
# HackrLink : ['https://hackr.io/tutorial/user-experience-research-and-design-specialization', 'https://hackr.io/tutorial/user-research-what-it-is-and-why-you-should-do', 'https://hackr.io/tutorial/learn-user-centered-design-with-ux-research-strategy', 'https://hackr.io/tutorial/user-research-mastery', 'https://hackr.io/tutorial/the-practical-beginners-guide-to-user-research', 'https://hackr.io/tutorial/how-to-conduct-user-experience-research-like-a-professional', 'https://hackr.io/tutorial/7-great-tried-and-tested-ux-research-techniques']
#
# CourseLink : ['https://click.linksynergy.com/deeplink?id=jU79Zysihs4&mid=40328&murl=https://www.coursera.org/specializations/michiganux', 'https://www.interaction-design.org/literature/article/user-research-what-it-is-and-why-you-should-do-it', 'http://share.trydesignlab.com/hackriouxsc', 'http://courses.sarahdoody.com/p/user-research-mastery', 'https://www.uxpin.com/studio/blog/the-practical-beginners-guide-to-user-research/', 'https://careerfoundry.com/en/blog/ux-design/how-to-conduct-user-experience-research-like-a-professional/', 'https://www.interaction-design.org/literature/article/7-great-tried-and-tested-ux-research-techniques']
#
# CourseCost : ['Paid', 'Free', 'Paid', 'Paid', 'Free', 'Free', 'Free']
#
# CourseType : ['Video', None, 'Beginner', 'Advanced', None, None, 'Video']
#
# StudentType : ['Beginner', 'Beginner', 'Certification', None, 'Beginner', 'Beginner', 'Beginner']

# %%
import pandas as pd
UXResearchCourses = pd.DataFrame({'Course': CourseTitles,
'Votes': Votes,
"Course Link":CourseLink,
"Author ":AuthorName,
"Author Link":AuthorLink,
"Hackr Link":HackrLink,
"Course Cost":CourseCost,
"Course Type":CourseType,
"Course Cost":CourseCost,
"Student Type":StudentType
})
print(UXResearchCourses.info())
UXResearchCourses
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Course        7 non-null      object
#  1   Votes         7 non-null      object
#  2   Course Link   7 non-null      object
#  3   Author        7 non-null      object
#  4   Author Link   7 non-null      object
#  5   Hackr Link    7 non-null      object
#  6   Course Cost   7 non-null      object
#  7   Course Type   4 non-null      object
#  8   Student Type  6 non-null      object
# dtypes: object(9)
# memory usage: 632.0+ bytes
# None
#                                               Course Votes  \
# 0  User Experience Research and Design Specializa...     1
# 1  User Research: What It Is And Why You Should D...     2
# 2  Learn User-Centered Design with UX Research & ...     1
# 3                              User Research Mastery    +1
# 4    The Practical Beginner’s Guide to User Research    +1
# 5  How To Conduct User Experience Research Like A...    +1
# 6   7 Great, Tried and Tested UX Research Techniques    +1
#
#                                          Course Link  Author   \
# 0  https://click.linksynergy.com/deeplink?id=jU79...  Saurabh
# 1  https://www.interaction-design.org/literature/...    Rajat
# 2          http://share.trydesignlab.com/hackriouxsc  Manuela
# 3  http://courses.sarahdoody.com/p/user-research-...  Saurabh
# 4  https://www.uxpin.com/studio/blog/the-practica...     Jack
# 5  https://careerfoundry.com/en/blog/ux-design/ho...     Jack
# 6  https://www.interaction-design.org/literature/...     Jack
#
#                       Author Link  \
# 0  https://hackr.io/saurabh-hooda
# 1  https://hackr.io/rajat-patel-3
# 2  https://hackr.io/manuela-odell
# 3  https://hackr.io/saurabh-hooda
# 4   https://hackr.io/jack-avery-1
# 5   https://hackr.io/jack-avery-1
# 6   https://hackr.io/jack-avery-1
#
#                                           Hackr Link Course Cost Course Type  \
# 0  https://hackr.io/tutorial/user-experience-rese...        Paid       Video
# 1  https://hackr.io/tutorial/user-research-what-i...        Free        None
# 2  https://hackr.io/tutorial/learn-user-centered-...        Paid    Beginner
# 3    https://hackr.io/tutorial/user-research-mastery        Paid    Advanced
# 4  https://hackr.io/tutorial/the-practical-beginn...        Free        None
# 5  https://hackr.io/tutorial/how-to-conduct-user-...        Free        None
# 6  https://hackr.io/tutorial/7-great-tried-and-te...        Free       Video
#
#     Student Type
# 0       Beginner
# 1       Beginner
# 2  Certification
# 3           None
# 4       Beginner
# 5       Beginner
# 6       Beginner

# %%
UXResearchCourses.to_csv('UXResearchCourses.csv')
