# %%
#import libraries
import requests
import re
from bs4 import BeautifulSoup
from requests import get
url = "https://hackr.io/tutorials/learn-design-thinking"
response = get(url)
#We’ll now create a BeautifulSoup object, or a parse tree. This object takes as its arguments the page.text document from Requests (the content of the server’s response) and then parses it from Python’s built-in html.parser.
soup = BeautifulSoup(response.text, 'html.parser')

# Pull all text from the tuturial divison that contains course listing
courses = soup.find_all('div', class_ ="tut-list tut-list-new tut-row")
print(type(courses))
print(len(courses))
# Out:
# <class 'bs4.element.ResultSet'>
# 9

# %% [markdown]
# Now we’ll select each container, and extract, by turn, each item of interest:
#
# - Course title
# - Votes
# - Author
# - Links (Course, Author, Hackr)
# - Course Features: (Free / Paid) (video / book ) (Beginner / Intermediate / Advanced)

# %%
# Lists to store the scraped data in
CourseTitles = []
Votes = []
CourseLink = []
AuthorName = []
AuthorLink = []
HackrLink = []
CourseCost = []
CourseType = []
StudentType = []


    
for course in courses:
    CourseTitle = course.div.find('span', class_ = 'tutorial-title-txt').text.strip()
    CourseTitles.append(CourseTitle)


    NoOfVote  = course.div.find('span', class_ = 'count').text.strip()
    Votes.append(NoOfVote)

    Link1 = course.find("div", class_="title-links no-margin").find('a')["href"]
    CourseLink.append(Link1)
    
    Name = course.find("a", class_="author no-marginright paddingleft-xs")
    if Name is None:
        AuthorName.append(None)
    else:
        Names=Name.text.strip()
        AuthorName.append(Names)
    
    auth  = course.find("div", class_="action author").find('a')
    if auth is None:
        AuthorLink.append(None)
    else:
        Link2 = auth["href"]
        AuthorLink.append(Link2)
    
    hackr = course.find("a", attrs={'href': re.compile("https://hackr.io/tutorial/")}) 
    if hackr is None:
        HackrLink.append(None)
    else:
        Link3=hackr.get("href")
        HackrLink.append(Link3)
        
    features  = course.find_all('div', class_ = "tut-label-group marginright-sm")
    for future in features:
        x=future.text.split()
    feat1 = x[0]
    if len(x) > 2:
        feat2 = x[1]
        feat3 = x[2]
    elif x[1] == ("Beginner" or "Advanced"):
        feat2 =None
        feat3= x[1]
    else:
        feat2 = x[1]
        feat3 = None
    CourseCost.append(feat1)
    CourseType.append(feat2)
    StudentType.append(feat3)
        

print (f"Courses : {CourseTitles}\n")
print (f"Votes : {Votes}\n")
print (f"CourseLink : {CourseLink}\n")
print (f"Author : {AuthorName}\n")
print (f"AuthorLink : {AuthorLink}\n")
print (f"HackrLink : {HackrLink}\n")
print (f"CourseLink : {CourseLink}\n")
print (f"CourseCost : {CourseCost}\n")
print (f"CourseType : {CourseType}\n")
print (f"StudentType : {StudentType}\n")
# Out:
# Courses : ['A virtual Crash Course in Design Thinking', 'Design Sprint Methodology', 'Design Thinking As a Strategy For Innovation', 'Unlock Your Creativity With Design 101', 'Web Design for Everybody', "Design Thinking: The Beginner's Guide", 'Design Thinking for Innovation', 'Design-Led Strategy: Design thinking for business strategy and entrepreneurship', '5 Stages in Design Thinking Process']
#
# Votes : ['8', '5', '5', '3', '1', '1', '+1', '+1', '+1']
#
# CourseLink : ['https://dschool.stanford.edu/resources-collections/a-virtual-crash-course-in-design-thinking', 'https://designsprintkit.withgoogle.com/methodology/overview', 'http://www.creativityatwork.com/design-thinking-strategy-for-innovation/', 'http://share.trydesignlab.com/hackriodesign101', 'https://click.linksynergy.com/deeplink?id=jU79Zysihs4&mid=40328&murl=https://www.coursera.org/specializations/web-design', 'https://www.interaction-design.org/courses/design-thinking-the-beginner-s-guide', 'https://click.linksynergy.com/deeplink?id=jU79Zysihs4&mid=40328&murl=https://www.coursera.org/learn/uva-darden-design-thinking-innovation', 'https://click.linksynergy.com/deeplink?id=jU79Zysihs4&mid=40328&murl=https://www.coursera.org/learn/design-strategy', 'https://www.interaction-design.org/literature/article/5-stages-in-the-design-thinking-process']
#
# Author : ['Jack', 'Parul', 'Pawan', 'Manuela', 'Saurabh', 'Jack', 'Saurabh', 'Kevin', None]
#
# AuthorLink : ['https://hackr.io/jack-avery-1', 'https://hackr.io/parul-bhargava-1', 'https://hackr.io/pawan-kumar-2', 'https://hackr.io/manuela-odell', 'https://hackr.io/saurabh-hooda', 'https://hackr.io/jack-avery-1', 'https://hackr.io/saurabh-hooda', 'https://hackr.io/kevin-yamato', None]
#
# HackrLink : ['https://hackr.io/tutorial/a-virtual-crash-course-in-design-thinking', 'https://hackr.io/tutorial/design-sprint-methodology', 'https://hackr.io/tutorial/design-thinking-as-a-strategy-for-innovation', 'https://hackr.io/tutorial/unlock-your-creativity-with-design-101', 'https://hackr.io/tutorial/web-design-for-everybody', 'https://hackr.io/tutorial/design-thinking-the-beginners-guide', 'https://hackr.io/tutorial/design-thinking-for-innovation', 'https://hackr.io/tutorial/design-led-strategy-design-thinking-for-business-strategy-and-entrepreneurship', None]
#
# CourseLink : ['https://dschool.stanford.edu/resources-collections/a-virtual-crash-course-in-design-thinking', 'https://designsprintkit.withgoogle.com/methodology/overview', 'http://www.creativityatwork.com/design-thinking-strategy-for-innovation/', 'http://share.trydesignlab.com/hackriodesign101', 'https://click.linksynergy.com/deeplink?id=jU79Zysihs4&mid=40328&murl=https://www.coursera.org/specializations/web-design', 'https://www.interaction-design.org/courses/design-thinking-the-beginner-s-guide', 'https://click.linksynergy.com/deeplink?id=jU79Zysihs4&mid=40328&murl=https://www.coursera.org/learn/uva-darden-design-thinking-innovation', 'https://click.linksynergy.com/deeplink?id=jU79Zysihs4&mid=40328&murl=https://www.coursera.org/learn/design-strategy', 'https://www.interaction-design.org/literature/article/5-stages-in-the-design-thinking-process']
#
# CourseCost : ['Free', 'Free', 'Free', 'Paid', 'Paid', 'Paid', 'Free', 'Paid', 'Free']
#
# CourseType : ['Video', None, 'Advanced', 'Beginner', 'Video', 'Video', 'Video', 'Video', None]
#
# StudentType : ['Beginner', 'Beginner', None, 'Certification', 'Beginner', 'Advanced', 'Beginner', 'Advanced', 'Beginner']

# %%
import pandas as pd
DesignThinkingCourses = pd.DataFrame({'Course': CourseTitles,
'Votes': Votes,
"Course Link":CourseLink,
"Author ":AuthorName,
"Author Link":AuthorLink,
"Hackr Link":HackrLink,
"Course Cost":CourseCost,
"Course Type":CourseType,
"Course Cost":CourseCost,
"Student Type":StudentType
})
print(DesignThinkingCourses.info())
DesignThinkingCourses
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Course        9 non-null      object
#  1   Votes         9 non-null      object
#  2   Course Link   9 non-null      object
#  3   Author        8 non-null      object
#  4   Author Link   8 non-null      object
#  5   Hackr Link    8 non-null      object
#  6   Course Cost   9 non-null      object
#  7   Course Type   7 non-null      object
#  8   Student Type  8 non-null      object
# dtypes: object(9)
# memory usage: 776.0+ bytes
# None
#                                               Course Votes  \
# 0          A virtual Crash Course in Design Thinking     8
# 1                          Design Sprint Methodology     5
# 2       Design Thinking As a Strategy For Innovation     5
# 3             Unlock Your Creativity With Design 101     3
# 4                           Web Design for Everybody     1
# 5              Design Thinking: The Beginner's Guide     1
# 6                     Design Thinking for Innovation    +1
# 7  Design-Led Strategy: Design thinking for busin...    +1
# 8                5 Stages in Design Thinking Process    +1
#
#                                          Course Link  Author   \
# 0  https://dschool.stanford.edu/resources-collect...     Jack
# 1  https://designsprintkit.withgoogle.com/methodo...    Parul
# 2  http://www.creativityatwork.com/design-thinkin...    Pawan
# 3     http://share.trydesignlab.com/hackriodesign101  Manuela
# 4  https://click.linksynergy.com/deeplink?id=jU79...  Saurabh
# 5  https://www.interaction-design.org/courses/des...     Jack
# 6  https://click.linksynergy.com/deeplink?id=jU79...  Saurabh
# 7  https://click.linksynergy.com/deeplink?id=jU79...    Kevin
# 8  https://www.interaction-design.org/literature/...     None
#
#                          Author Link  \
# 0      https://hackr.io/jack-avery-1
# 1  https://hackr.io/parul-bhargava-1
# 2     https://hackr.io/pawan-kumar-2
# 3     https://hackr.io/manuela-odell
# 4     https://hackr.io/saurabh-hooda
# 5      https://hackr.io/jack-avery-1
# 6     https://hackr.io/saurabh-hooda
# 7      https://hackr.io/kevin-yamato
# 8                               None
#
#                                           Hackr Link Course Cost Course Type  \
# 0  https://hackr.io/tutorial/a-virtual-crash-cour...        Free       Video
# 1  https://hackr.io/tutorial/design-sprint-method...        Free        None
# 2  https://hackr.io/tutorial/design-thinking-as-a...        Free    Advanced
# 3  https://hackr.io/tutorial/unlock-your-creativi...        Paid    Beginner
# 4  https://hackr.io/tutorial/web-design-for-every...        Paid       Video
# 5  https://hackr.io/tutorial/design-thinking-the-...        Paid       Video
# 6  https://hackr.io/tutorial/design-thinking-for-...        Free       Video
# 7  https://hackr.io/tutorial/design-led-strategy-...        Paid       Video
# 8                                               None        Free        None
#
#     Student Type
# 0       Beginner
# 1       Beginner
# 2           None
# 3  Certification
# 4       Beginner
# 5       Advanced
# 6       Beginner
# 7       Advanced
# 8       Beginner

# %%
DesignThinkingCourses.to_csv('DesignThinkingCourses.csv')
