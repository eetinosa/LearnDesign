# %%
#import libraries
import requests
from bs4 import BeautifulSoup
from requests import get
url = "https://hackr.io/tutorials/learn-user-experience-design"

# %%
response = get(url)
#Print a small part of response‘s content by accessing its .text attribute
print(response.text[:1500])
# Out:
# <!DOCTYPE html>
# <html itemscope itemtype="http://schema.org/WebPage" lang="en">
# <head>
#     <link rel="dns-prefetch" href="https://use.typekit.net"> <link rel="dns-prefetch" href="https://securepubads.g.doubleclick.net"> <link rel="dns-prefetch" href="https://adservice.google.co.in"> <link rel="dns-prefetch" href="https://adservice.google.com">    <meta charset="utf-8">
#     <link rel="manifest" href="https://hackr.io/manifest.json?v=1.1">
#     <link rel="apple-touch-icon" sizes="180x180" href="https://hackr.io/assets/images/programming-images/programming-apple-touch-icon.png">
#     <link rel="apple-touch-icon-precomposed apple-touch-icon" href="https://hackr.io/assets/images/programming-images/programming-apple-touch-icon-precomposed.png">
# ...

# %% [markdown]
# We’ll now create a BeautifulSoup object, or a parse tree. This object takes as its arguments the page.text document from Requests (the content of the server’s response) and then parses it from Python’s built-in html.parser.

# %%
from bs4 import BeautifulSoup
# Collect and parse first page
soup = BeautifulSoup(response.text, 'html.parser')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en">
# <head>
# <link href="https://use.typekit.net" rel="dns-prefetch"/> <link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/> <link href="https://adservice.google.co.in" rel="dns-prefetch"/> <link href="https://adservice.google.com" rel="dns-prefetch"/> <meta charset="utf-8"/>
# <link href="https://hackr.io/manifest.json?v=1.1" rel="manifest"/>
# <link href="https://hackr.io/assets/images/programming-images/programming-apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://hackr.io/assets/images/programming-images/programming-apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon"/>
# ...

# %%
# Pull all text from the tuturial divison that contains course listing
courses = soup.find_all('div', class_ ="tut-list tut-list-new tut-row")
print(type(courses))
print(len(courses))
# Out:
# <class 'bs4.element.ResultSet'>
# 11

# %% [markdown]
# Now we’ll select only the first container, and extract, by turn, each item of interest:
#
# - Course title
# - Votes
# - Link
# - Course Features: (Free / Paid) (video / book ) (Beginner / Intermediate / Advanced)

# %%
first_course = courses[0]
first_course
# Out:
# <div class="tut-list tut-list-new tut-row"> <div class="tut-list-primary"> <div class="tut-vote"> <a class="vote-widget login-required" data-id="10417" data-message="  You need to Sign up to upvote" data-topic="User Interface Design" data-trigger="upvote_tutuorial_btn" data-url="https://hackr.io/tutorial/create-pixel-perfect-work-with-ui-design/vote" href="javascript:void(0)"> <span class="arrow"> <img class="arrow-img gray" height="11" loading="lazy" src="https://hackr.io/assets/images/header-icons/caret-up.svg" width="11"/> </span> <span class="count">3</span> <span class="tut-upvotes-text hidden">Upvotes</span> </a> </div> <div class="tut-title with-tags"> <div class="title"> <div class="title-links no-margin"> <div class="title-tags"> <div class="label label-new" data-container="body" data-content="This tutorial was recently submitted to Hackr.io" data-placement="bottom" data-toggle="popover" data-trigger="hover" style="cursor: initial;" tabindex="0"> <i class="ion-ios-medical"><
# ...

# %%
course_title  = first_course.div.find('span', class_ = 'tutorial-title-txt')
course_title.text.strip()
# Out:
# 'Create Pixel Perfect Work with UI Design'

# %%
vote=first_course.a.text
vote.strip()
# Out:
# '3 Upvotes'

# %%
import re
links  = first_course.find_all("a", attrs={'href': re.compile("http")})
for link in links:
    print (link.get("href"))
# Out:
# http://share.trydesignlab.com/hackrioui
# https://hackr.io/manuela-odell
# https://hackr.io/tutorial/create-pixel-perfect-work-with-ui-design

# %%
features  = first_course.find_all('span', class_ = "tag-tooltip tag-select label label-xs label-primary")
for feature in features:
    print (feature.text.strip())
# Out:
# Paid
# Advanced
# Certification

# %% [markdown]
# Repeat for second course

# %%
second_course = courses[1]
second_course
# Out:
# <div class="tut-list tut-list-new tut-row"> <div class="tut-list-primary"> <div class="tut-vote"> <a class="vote-widget login-required" data-id="5518" data-message="  You need to Sign up to upvote" data-topic="User Interface Design" data-trigger="upvote_tutuorial_btn" data-url="https://hackr.io/tutorial/ui-web-design-for-beginners/vote" href="javascript:void(0)"> <span class="arrow"> <img class="arrow-img gray" height="11" loading="lazy" src="https://hackr.io/assets/images/header-icons/caret-up.svg" width="11"/> </span> <span class="count">19</span> <span class="tut-upvotes-text hidden">Upvotes</span> </a> </div> <div class="tut-title"> <div class="title"> <div class="title-links no-margin"> <a class="js-tutorial-title marginright-sm" data-tutorialid="5518" data-tutorialrank="1" href="https://www.youtube.com/watch?v=QJ9ygdD2sIY" rel="nofollow" target="_blank"> <span class="tutorial-title-txt">UI &amp; Web-design for Beginners</span> <span class="tut-title-link"> <span data-id="5518" 
# ...

# %%
course_title  = second_course.div.find('span', class_ = 'tutorial-title-txt')
course_title.text.strip()
# Out:
# 'UI & Web-design for Beginners'

# %%
vote=second_course.a.text
vote.strip()
# Out:
# '19 Upvotes'

# %%
links  = second_course.find_all("a", attrs={'href': re.compile("http")})
for link in links:
    print (link.get("href"))
# Out:
# https://www.youtube.com/watch?v=QJ9ygdD2sIY
# https://hackr.io/jack-avery-1
# https://hackr.io/tutorial/ui-web-design-for-beginners

# %%
features  = second_course.find_all('span', class_ = "tag-tooltip tag-select label label-xs label-primary")
for feature in features:
    print (feature.text.strip())
# Out:
# Free
# Video
# Beginner

# %% [markdown]
# **The script for a single page**
#
# Before piecing together what we’ve done so far, we have to make sure that we’ll extract the data only from all the courses. So we don't have incomplete data

# %%
# Lists to store the scraped data in
CourseTitles = []
Votes = []
CourseLinks = []
CourseFeatures = []

fields = ['CourseTitles', 'Votes','CourseLinks', 'CourseFeatures'] 
filename = "UXDesign_Courses.csv"

import csv
with open(filename, 'w', newline = '') as csvfile: 
    
    # creating a csv dict writer object 
    writer = csv.DictWriter(csvfile, fieldnames = fields) 
    #G = csv.writer(open('IllustratorCourses.csv', 'w'))
    # Extract data from individual jobs
    # writing headers (field names) 
    
    writer.writeheader() 
    
    for course in courses:
          
            
    # The CourseTitle
            CourseTitle = course.div.find('span', class_ = 'tutorial-title-txt').text.strip()
            print (f"Courses : {CourseTitle}")
            #f.writerow(['CourseTitle'])
        # The NoOfVotes
            #mydict=[{'CourseTitles':CourseTitle, 'NoOfVotes':NoOfVote ,'links':link, 'detail': details}]

            NoOfVote  = course.a.text.strip()
            print (f"Votes : {NoOfVote}" )
            #f.writerow([ 'NoOfVote'])
        # The Links
            #mydict=[{'CourseTitles':CourseTitle, 'NoOfVotes':NoOfVote ,'links':link, 'detail': details}]

            ref = course.find_all("a",attrs={'href': re.compile("https://")})
            for x in ref:
                link = x.get("href") 
                print (f"Links : {link}" )
                #f.writerow(['link'])
            #mydict=[{'CourseTitles':CourseTitle, 'NoOfVotes':NoOfVote ,'links':link, 'detail': details}]

            dets  = course.find_all('span', class_ = "tag-tooltip tag-select label label-xs label-primary")
            for ty in dets:
                details= ty.text.strip()
                print(f"Features : {details}" )
                #f.writerow(['details'])
            #about.append(det2)
            #about3.append(det3)
            #print(f"Link")
            
            print ('')
           # G.writerows(['CourseTitle', 'NoOfVote','link', 'details'])
            mydict=[{'CourseTitles':CourseTitle, 'Votes':NoOfVote ,'CourseLinks':link, 'CourseFeatures': details}]



                # writing headers (field names) 
                #writer.writeheader() 

            # writing data rows 
            writer.writerows(mydict)
# Out:
# Courses : Create Pixel Perfect Work with UI Design
# Votes : 3 Upvotes
# Links : https://hackr.io/manuela-odell
# Links : https://hackr.io/tutorial/create-pixel-perfect-work-with-ui-design
# Features : Paid
# Features : Advanced
# Features : Certification
#
# Courses : UI & Web-design for Beginners
# Votes : 19 Upvotes
# Links : https://www.youtube.com/watch?v=QJ9ygdD2sIY
# Links : https://hackr.io/jack-avery-1
# Links : https://hackr.io/tutorial/ui-web-design-for-beginners
# Features : Free
# Features : Video
# Features : Beginner
#
# Courses : Learn UI Design
# Votes : 3 Upvotes
# Links : https://hackr.io/jack-avery-1
# Links : https://hackr.io/tutorial/learn-ui-design
# Features : Paid
# Features : Video
# Features : Beginner
#
# Courses : Material Design
# Votes : 3 Upvotes
# Links : https://material.io/design/
# Links : https://hackr.io/himanshu-vaishnav
# Links : https://hackr.io/tutorial/material-design
# Features : Free
# Features : Beginner
#
# ...

# %%
import pandas as pd
Design_df = pd.DataFrame({'Course': CourseTitles,
'Votes': NoOfVotes,
"Course Link":HackrLink,
"Course Details":abt,
})
print(Design_df.info())
Design_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-a2e6ccd08c80> in <module>
#       1 import pandas as pd
# ----> 2 Design_df = pd.DataFrame({'Course': CourseTitles,
#       3 'Votes': NoOfVotes,
#       4 "Course Link":HackrLink,
#       5 "Course Details":abt,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# ...

# %%
Design_df.to_csv('Design.csv')

# %% [markdown]
# **The script for multiple pages**
#
# We’ll build upon our one-page script by doing three more things:
#
# - Making all the requests we want from within the loop.
# - Controlling the loop’s rate to avoid bombarding the server with requests.
# - Monitoring the loop while it runs.

# %% [markdown]
# **How do the URLs change when you navigate to the next results page?**
