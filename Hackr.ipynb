# %%
import requests
from requests import get
url = "https://hackr.io/tutorials/learn-software-design-patterns?q=design"

# %%
response = get(url)
#Print a small part of response‘s content by accessing its .text attribute
print(response.text[:1500])
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     308         # Add certificate verification
# --> 309         conn = self._new_conn()
#     310         hostname = self.host
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170         except SocketError as e:
# --> 171             raise NewConnectionError(
#     172                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x0000022A60684E20>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     445         if new_retry.is_exhausted():
# --> 446             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     447
#
# MaxRetryError: HTTPSConnectionPool(host='hackr.io', port=443): Max retries exceeded with url: /tutorials/learn-software-design-patterns?q=design (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A60684E20>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-2-d05ad75490a2> in <module>
# ----> 1 response = get(url)
#       2 #Print a small part of response‘s content by accessing its .text attribute
#       3 print(response.text[:1500])
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='hackr.io', port=443): Max retries exceeded with url: /tutorials/learn-software-design-patterns?q=design (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022A60684E20>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %% [markdown]
# Let's search for a content - (design)

# %%
# let's try a string search
loc = str(response.text).find('design')
loc
# Out:
# 1549

# %% [markdown]
# This identifies the location of the word (engineer)

# %%
#Print around the location to know what the text is
response.content[loc-100:loc+100]
# Out:
# b'X-UA-Compatible" content="IE=edge">\n          <link href="https://hackr.io/tutorials/learn-software-design-patterns" rel="canonical" />\n                  <link rel="next" href="https://hackr.io/tutori'

# %% [markdown]
# - Import the BeautifulSoup class creator from the package bs4.
# - Parse response.text by creating a BeautifulSoup object, and assign this object to html_soup. The 'html.parser' argument indicates that we want to do the parsing using Python’s built-in HTML parser.

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text)
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en">
# <head>
# <link href="https://use.typekit.net" rel="dns-prefetch"/> <link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/> <link href="https://adservice.google.co.in" rel="dns-prefetch"/> <link href="https://adservice.google.com" rel="dns-prefetch"/> <meta charset="utf-8"/>
# <link href="https://hackr.io/manifest.json?v=1.1" rel="manifest"/>
# <link href="https://hackr.io/assets/images/programming-images/programming-apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://hackr.io/assets/images/programming-images/programming-apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon"/>
# <link href="https://hackr.io/assets/images/programming-images/programming-favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="https://hackr.io/assets/images/programming-images/programming-favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link color="#5bbad5" href="https://hackr.io/assets/images/programming-images/programming-safari-pinned-tab.svg" rel="mask-icon"/>
# <link as="style" href="https://use.typekit.net/dys0hhf.css" rel="prefetch"/>
# <link as="script" href="https://hackr.io/admin/js/bootstrap/bootstrap.min.js" rel="prefetch"/>
# <meta content="#3C7DC0" name="theme-color"/>
# <link href="" rel="dns-prefetch"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://hackr.io/tutorials/learn-software-design-patterns" rel="canonical"/>
# <link href="https://hackr.io/tutorials/learn-software-design-patterns/page/2" rel="next"/>
# <link href="https://hackr.io/tutorials/learn-software-design-patterns/amp" rel="amphtml"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=5.0, minimum-scale=1.0, user-scalable=yes" name="viewport"/>
# <link href="https://hackr.io/programming/rss.xml" rel="alternate" title="Latest Programming Tutorials" type="application/rss+xml"/>
# <style> :root { --theme-primary: #007aff; --theme-primary-bg: #eef4fa; --theme-primary-light: #b1d6ff; --theme-primary-dark: #0052de; --theme-primary-toneddown: #0071eb; --theme-primary-hover: #005ec4; } </style>
# <title>Learn Design Patterns - Best Design Patterns Tutorials | Hackr.io</title>
# <meta content="Learning Design Patterns? Check out these best online Design Patterns courses and tutorials recommended by the programming community. Pick the tutorial as per your learning style: video tutorials or a book. Free course or paid. Tutorials for beginners or advanced learners. Check Design Patterns community's reviews &amp;amp; comments." name="description"/>
# <meta content="Learn Design Patterns - Best Design Patterns Tutorials | Hackr.io" itemprop="name"/>
# <meta content="Learning Design Patterns? Check out these best online Design Patterns courses and tutorials recommended by the programming community. Pick the tutorial as per your learning style: video tutorials or a book. Free course or paid. Tutorials for beginners or advanced learners. Check Design Patterns community's reviews &amp; comments." itemprop="description"/>
# <meta content="https://hackr.io/tutorials/learn-software-design-patterns/logo/logo-software-design-patterns?ver=1557508472" itemprop="image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@hackrio_" name="twitter:creator"/>
# <meta content="Learning Design Patterns? Check out these best online Design Patterns courses and tutorials recommended by the programming community. Pick the tutorial as per your learning style: video tutorials or a book. Free course or paid. Tutorials for beginners or advanced learners. Check Design Patterns community's reviews &amp; comments." name="twitter:description"/>
# <meta content="https://hackr.io/tutorials/learn-software-design-patterns/logo/logo-software-design-patterns?ver=1557508472" name="twitter:image"/>
# <meta content="Learn Design Patterns - Best Design Patterns Tutorials | Hackr.io" name="twitter:image:alt"/>
# <meta content="Learn Design Patterns - Best Design Patterns Tutorials | Hackr.io" property="og:title"/>
# <meta content="Learning Design Patterns? Check out these best online Design Patterns courses and tutorials recommended by the programming community. Pick the tutorial as per your learning style: video tutorials or a book. Free course or paid. Tutorials for beginners or advanced learners. Check Design Patterns community's reviews &amp;amp; comments." property="og:description"/>
# <meta content="https://hackr.io/tutorials/learn-software-design-patterns" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="Hackr.io" property="og:site_name"/>
# <meta content="1457383854551756" property="og:fb:app_id"/>
# <meta content="https://hackr.io/tutorials/learn-software-design-patterns/logo/logo-software-design-patterns?ver=1557508472" property="og:image"/>
# <meta content="@hackrio_" name="twitter:site"/>
# <meta content="Learn Design Patterns - Best Design Patterns Tutorials | Hackr.io" name="twitter:title"/>
# <meta content="J7sct78WY26juyvCCd8HE3TjDYKRH3GFD9x0D9J5" name="csrf-token"/>
# <!-- analytics -->
# <!-- end Optimize Page Hiding Snippet -->
# <script>
#       (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#       (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#       m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#       })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#       ga('create', 'UA-47735927-8', 'auto');
#             ga('set', 'dimension1', 'loggedout');
#
#
#       var user_id_ga = "";
#       if(user_id_ga) {
#         ga('set', 'userId', user_id_ga);
#       }
#
#       ga('send', 'pageview');
#       ga('set', 'transport', 'beacon');
#
#         </script>
# <!-- start Mixpanel --><script type="text/javascript">(function(c,a){if(!a.__SV){var b=window;try{var d,m,j,k=b.location,f=k.hash;d=function(a,b){return(m=a.match(RegExp(b+"=([^&]*)")))?m[1]:null};f&&d(f,"state")&&(j=JSON.parse(decodeURIComponent(d(f,"state"))),"mpeditor"===j.action&&(b.sessionStorage.setItem("_mpcehash",f),history.replaceState(j.desiredHash||"",c.title,k.pathname+k.search)))}catch(n){}var l,h;window.mixpanel=a;a._i=[];a.init=function(b,d,g){function c(b,i){var a=i.split(".");2==a.length&&(b=b[a[0]],i=a[1]);b[i]=function(){b.push([i].concat(Array.prototype.slice.call(arguments,
# 0)))}}var e=a;"undefined"!==typeof g?e=a[g]=[]:g="mixpanel";e.people=e.people||[];e.toString=function(b){var a="mixpanel";"mixpanel"!==g&&(a+="."+g);b||(a+=" (stub)");return a};e.people.toString=function(){return e.toString(1)+".people (stub)"};l="disable time_event track track_pageview track_links track_forms track_with_groups add_group set_group remove_group register register_once alias unregister identify name_tag set_config reset opt_in_tracking opt_out_tracking has_opted_in_tracking has_opted_out_tracking clear_opt_in_out_tracking people.set people.set_once people.unset people.increment people.append people.union people.track_charge people.clear_charges people.delete_user people.remove".split(" ");
# for(h=0;h<l.length;h++)c(e,l[h]);var f="set set_once union unset remove delete".split(" ");e.get_group=function(){function a(c){b[c]=function(){call2_args=arguments;call2=[c].concat(Array.prototype.slice.call(call2_args,0));e.push([d,call2])}}for(var b={},d=["get_group"].concat(Array.prototype.slice.call(arguments,0)),c=0;c<f.length;c++)a(f[c]);return b};a._i.push([b,d,g])};a.__SV=1.2;b=c.createElement("script");b.type="text/javascript";b.async=!0;b.src="undefined"!==typeof MIXPANEL_CUSTOM_LIB_URL?
# MIXPANEL_CUSTOM_LIB_URL:"file:"===c.location.protocol&&"//cdn4.mxpnl.com/libs/mixpanel-2-latest.min.js".match(/^\/\//)?"https://cdn4.mxpnl.com/libs/mixpanel-2-latest.min.js":"//cdn4.mxpnl.com/libs/mixpanel-2-latest.min.js";d=c.getElementsByTagName("script")[0];d.parentNode.insertBefore(b,d)}})(document,window.mixpanel||[]);
# mixpanel.init("056417f085ec3cecac0b7d2fae1b5314");</script><!-- end Mixpanel -->
# <script async="async" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#       var googletag = googletag || {};
#       googletag.cmd = googletag.cmd || [];
#     </script>
# <script>
#       window.googletag = window.googletag || {cmd: []};
#       googletag.cmd.push(function() {
#         var mapping1 = googletag.sizeMapping().
#     addSize([748, 0], [[728,90]]).
#     addSize([0, 0], [[300, 250]]).
#     build();
#         googletag.defineSlot('/21791262717/Hackr_Programming_Middle_Center', [[300, 250], [728, 90]],'div-gpt-ad-1569593792491-0').defineSizeMapping(mapping1).addService(googletag.pubads());
#         googletag.defineSlot('/21791262717/Hack_Tutorials_MC_Mobile', [300, 250], 'div-gpt-ad-1563361940668-0').addService(googletag.pubads());
#         googletag.defineSlot('/21791262717/Hack_Tutorials_MC_Desktop', [728, 90], 'div-gpt-ad-1563361986852-0').addService(googletag.pubads());
#         googletag.defineSlot('/21791262717/Hack_Blogs_TRS', [300, 250], 'div-gpt-ad-1569594507859-0').addService(googletag.pubads());
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
#       });
#     </script>
# <link href="https://hackr.io/tutorials/learn-software-design-patterns?q=design" hreflang="en" rel="alternate"/>
# <link href="https://hackr.io/es/tutorials/learn-software-design-patterns?q=design" hreflang="es" rel="alternate"/>
# <link href="https://hackr.io/ru/tutorials/learn-software-design-patterns?q=design" hreflang="ru" rel="alternate"/>
# <meta content="1457383854551756" property="fb:app_id"/>
# <!-- SetupAd Header Bidding Tag -->
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <style> .btn-as-link-mob{padding:5px 14px;border:1px solid var(--theme-primary)}.form-control{border-radius:3px;font-weight:400;height:42px;padding:6px 12px 8px;border-color:#d9d9d9;box-shadow:none;appearance:none}.form-control:focus{border-color:var(--theme-primary)}.form-control{height:50px;font-size:14px;font-weight:400}.js-open-submit-tutorial{box-shadow:none}.fx{display:flex}body{font-family:-apple-system,BlinkMacSystemFont,'Segoe UI',Roboto,sans-serif;font-weight:400;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;color:#383838;background-color:#fafafa;opacity:1;transition:.3s all linear}@media (max-width:767px){body{overflow-x:hidden;min-height:calc(100vh -190px)}}body .form-control:focus{box-shadow:none}input[type=text]{-webkit-appearance:none}@media (min-width:1024px){.container{max-width:960px}}.navbar-brand{flex:0 auto}@media (min-width:768px) and (max-width:1023px){.navbar-brand{margin-left:0!important}}@media (min-width:1024px){.navbar-brand{margin-left:0!important}}@media (max-width:767px){.navbar-brand{display:block}}.navbar-brand img{height:25px;width:auto}@media (max-width:767px){.navbar-brand img{height:24px;width:auto}}.navbar{padding:0;background-color:#fff;transition:all .1s linear;z-index:5000!important;border-bottom:1px solid #eee}.navbar .container{width:100%;max-width:1200px}@media (min-width:768px) and (max-width:1023px){.navbar .container{padding-left:30px;padding-right:30px}}@media (max-width:767px){.navbar .navbar-holder{padding:10px}}@media (min-width:768px) and (max-width:1023px){.navbar .navbar-holder{padding:10px 20px}}.navbar .nav-main{display:flex;align-items:center;justify-content:space-between;width:100%}.navbar .left{display:flex;align-items:center;margin-right:15px}.navbar .navbar-header{display:flex;align-items:center}.navbar .site-toggle{width:25px;height:25px;border:1px solid #eee;align-items:center;justify-content:center;border-radius:4px;display:flex}@media (min-width:1024px){.navbar .site-toggle{display:none}}@media (max-width:767px){.navbar .mobile-navbar-search{height:1px}}@media (max-width:767px){.navbar .mobile-navbar-search .nav-input{height:0;padding:0;border:none}}.navbar .mobile-navbar-search .icon{display:none}.navbar .form-holder{position:relative}@media (max-width:767px){.navbar .form-holder{z-index:499}.navbar .form-holder .navbarSearch{z-index:499}}@media (max-width:767px){.navbar .nav-icon-toggle{display:block}}@media (max-width:767px){.navbar .navbar-collapse{text-align:center}}.icon{position:absolute;top:50%;left:17px;transform:translateY(-50%) scale(1.1);opacity:.5;z-index:2;transition:all .2s linear}@media (max-width:767px){.icon{display:none}}.twitter-typeahead{display:block!important;width:100%;z-index:2}@media (max-width:767px){.homepage .navbar{opacity:0;min-height:55px}}@media (max-width:767px){.homepage .navbar.scrolled{opacity:1}}.homepage .navbar.scrolled .navbar-search .form-holder{display:block!important}.form-holder{position:relative}.navbar-nav{display:flex;align-items:center}@media (max-width:767px){.navbar-new{border-bottom:none}}.navbar-new .navbar-brand img{height:27px}@media (max-width:767px){.navbar-new .navbar-brand img{height:24px}}@media (min-width:992px) and (max-width:1024px){.navbar-new .navbar-brand img{height:22px}}.navbar-new .container{min-width:100%;margin:0 auto}@media (max-width:767px){.navbar-new .container{min-width:auto}}@media (min-width:1920px){.navbar-new .container{min-width:auto}}.navbar-new .navbar-holder{padding:15px 0 0}@media (max-width:767px){.navbar-new .navbar-holder{padding:10px}}.navbar-new .nav-main{border-bottom:1px solid #eee;margin:0;padding:0 60px 15px}@media (max-width:767px){.navbar-new .nav-main{padding:0;border-bottom:none}}@media (min-width:1920px){.navbar-new .nav-main{padding:0 400px 15px}}.navbar-new .navbar-header{display:block}@media (max-width:767px){.navbar-new .navbar-header{display:flex}}.navbar-new .right{flex:.8}@media (max-width:767px){.navbar-new .right{flex:0}}@media (min-w ...
# <body class="tutorials tutorials-page hackr-programming signin locale-en">
# <!-- Google Tag Manager (noscript) -->
# <!-- End Google Tag Manager (noscript) -->
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script> <!-- CM_HIO_BTF_ERSB -->
# <script type="application/ld+json">
#   {
#     "@context": "https://schema.org",
#     "@type": "Organization",
#     "url": "https://hackr.io",
#     "logo": "https://hackr.io/assets/images/logo-hi-res.png"
#   }
# </script>
# <nav class="navbar navbar-fixed-top scrolled navbar-new navbar-phase2 bg-lg" role="navigation"> <div class="container no-padding"> <div class="navbar-holder js-design-nav"> <div class="nav-main"> <div class="left"> <div class="navbar-header"> <a class="navbar-brand" href="https://hackr.io "> <img alt="logo" class="hackr-logo-text-path" src="https://hackr.io/assets/images/programming-images/logo-new.svg"/> </a> <div class="site-toggle marginleft-xs"> <img alt="select-site" class="arrow-icon" src="https://hackr.io/assets/images/header-icons/caret-down.svg"/> </div> <ul class="nav-header-list js-show-subnav"> <li class="nav-item active"> <a class="nav-link" href="https://hackr.io"> <span><img alt="Programming" class="nav-icon" src="https://hackr.io/assets/images/nav-icons/programming.svg"/></span> Programming </a> </li> <li class="nav-item"> <a class="nav-link" href="https://hackr.io/data-science"> <span><img alt="Data Science" class="nav-icon" src="https://hackr.io/sites/data-science/icon?ver=1571096418"/></span> Data Science </a> </li> <li class="nav-item"> <a class="nav-link" href="https://hackr.io/devops"> <span><img alt="DevOps" class="nav-icon" src="https://hackr.io/sites/devops/icon?ver=1576396835"/></span> DevOps </a> </li> <li class="nav-item"> <a class="nav-link" href="https://hackr.io/design"> <span><img alt="Design" class="nav-icon" src="https://hackr.io/sites/design/icon?ver=1571096431"/></span> Design </a> </li> </ul> </div> </div> <div class="right"> <div class="navbar-search hidden-xs"> <div class="form-holder"> <div class="navbarSearch search-anim-sec" id="scrollable-dropdown-menu"> <input class="typeahead nav-input search-animation js-search-animation active typeahead js-navbar-search-input" maxlength="50" name="input" placeholder="Search for topics" type="text" value="design"/> <img alt="loader" class="Typeahead-spinner hidden" src="https://raw.githubusercontent.com/twitter/typeahead.js/gh-pages/img/spinner.gif"/> </div> </div> </div> <div class="search-bar-toggle nav-icon-toggle visible-xs"> <img alt="search" height="12" src="https://hackr.io/assets/images/header-icons/search-header.svg" width="12"/> </div> <button class="nav-btn visible-xs btn btn-primary btn-as-link btn-as-link-mob mob-signup open-signup-modal" href="javascript:void(0);">Sign Up</button> <div class="navbar-collapse collapse js-nav-icon-hidden" id="navbarCollapse"> <ul class="nav navbar-nav"> <li> <a class="js-open-submit-tutorial submit submit-tutorial link login-required" data-message="You need to Sign up to submit a Tutorial" data-trigger="submit_tutorial_btn" href="#" title="Submit a tutorial"> <img alt="submit" class="icon-plus color-filter" src="https://hackr.io/assets/images/header-icons/add.svg" width="10"/> <span> Submit a tutorial</span> </a> </li> <li class="marginleft-submit"> <a class="padding-signup open-signup-modal"> Sign Up / Sign In</a> </li> </ul> </div> </div> </div> <div class="mobile-search visible-xs"> <div class="mobile-navbar-search search-bar"> <div class="form-holder"> <div class="navbarSearch"> <input class="typeahead form-control nav-input js-navbar-search-input" maxlength="50" placeholder="Search for topics" type="text" value="design"/> <img alt="loader" class="Typeahead-spinner hidden" src="https://raw.githubusercontent.com/twitter/typeahead.js/gh-pages/img/spinner.gif"/> </div> <img alt="search" class="icon" height="18" src="https://hackr.io/assets/images/header-icons/search-header.svg" width="18"/> </div> </div> </div> </div> <ul class="nav-header-list nav-header-list-mob js-show-subnav js-show-subnav-mob"> <li class="nav-item visible-sm visible-xs"> <a class="nav-link fx" href="https://hackr.io"> <span class="fx ai-c nav-link-item"> <img alt="Programming" class="nav-icon" src="https://hackr.io/assets/images/nav-icons/programming.svg"/>Programming </span> </a> </li> <li class="nav-item visible-sm visible-xs"> <a class="nav-link fx" href="https://hackr.io/data-science"> <span class="fx ai-c nav-link-item"> <img ...
# <input id="js-topic" type="hidden" value="Design Patterns"/>
# <input id="js-topic-slug" type="hidden" value="software-design-patterns"/>
# <input id="js-topic-id" type="hidden" value="415"/>
# <input id="js-filters-url" type="hidden" value="https://hackr.io/topics/software-design-patterns/filters-content"/>
# <!-- Page Header -->
# <div class="page--section no-padding">
# <!-- Page Section Header -->
# <div class="page--section-header tutorial--tut-title js-topic-header-side"> <div class="container alt"> <div class="row"> <div class="header-notice-wrapper minimised hidden-sec js-signup-infobar" data-category="Design Patterns"> <div class="container alt"> <div class="row"> <div class="col-xs-12 col-md-12"> <div class="panel intro-panel panel-primary"> <div class="panel-body notice-panel-body"> <a class="close-actions btn-minimise"> <i class="ion-ios-close"></i> </a> <div class="panel-left col-sm-3 col-md-5 panel-width-left"> <div class="notice-text"> <p class="notice-title-text no-margin">Hackr.io is a community to find and share the best online courses &amp; tutorials. Join them, it only takes 30 seconds.</p> </div> <div class="notice-cta"> <a class="btn btn-primary join-btn open-signup-modal text-capitalize">join</a> </div> </div> <div class="panel-right col-sm-9 col-md-7 panel-width-right"> <div class="row"> <div class="col-sm-12"> <p class="no-marginbottom paddingleft-xs"> <strong>Here's how it works:</strong> </p> </div> </div> <div class="row"> <div class="col-sm-4 text-center"> <img alt="share-icon" class="notice-sec-icon" height="50" src="https://hackr.io/assets/images/plus.svg"/> <p class="notice-subtitle">Anybody can submit a course or a tutorial</p> </div> <div class="col-sm-4 text-center"> <img alt="thumbs-up" class="notice-sec-icon" height="50" src="https://hackr.io/assets/images/like.svg"/> <p class="notice-subtitle">Community upvotes the useful tutorials</p> </div> <div class="col-sm-4 text-center"> <img alt="upwards-graph" class="notice-sec-icon" height="50" src="https://hackr.io/assets/images/graph.svg"/> <p class="notice-subtitle">The best tutorials rise to the top</p> </div> </div> </div> </div> <span class="disclaimer-text"><b>Disclosure:</b> This page may contain affliate links, meaning when you click the links and make a purchase, we receive a commission.</span> </div> </div> </div> </div> </div> <div class="col-xs-12 col-md-8"> <button class="hidden btn btn-primary marginleft-md" id="js-pushButton"></button> <div class="page--section-heading tut-section-heading fx wrap-mob fx-wrap fx--ai-fs fx--jc-fs page--heading-modified"> <div class="category-header-wrapper-mobile"> <div class="category-header"> <img alt="Learn Design Patterns from the best Design Patterns tutorials/courses online." class="tut-icon img--large" src="https://hackr.io/tutorials/software-design-patterns/logo-software-design-patterns.svg?ver=1557508472"/> <div class="tut-info"> <h1 class="tut-title">Design Patterns Tutorials and Courses</h1> <div class="tut-description hidden-xs"> <p class="subheading-16 page-header-subHeading marginbottom-md">Learn Design Patterns online from the best Software Design Patterns tutorials &amp; courses submitted &amp; voted by the programming community.</p> </div> </div> </div> <div class="tut-description tut-description-mobile"> <p class="page--section-subheading text-left">Learn Design Patterns online from the best Software Design Patterns tutorials &amp; courses submitted &amp; voted by the programming community.</p> </div> </div> </div> </div> <div class="col-xs-12 col-md-4 follow-right"> <div class="follow-block"> <h5 class="follow-heading">Follow this page to get notified about tutorials, blog posts, and more on Design Patterns</h5> <div class="follow-footer-sec fx fx--ai-c fx--jc-sb"> <div class="left-sec fx"> <div class="footer-text followers"> <h4 class="follow-numbers">109</h4> <p class="text text-capitalize">followers</p> </div> </div> <div class="follow-btnGrp"> <button class="js-follow-topic js-follow-btn btn btn-primary fw-bold follow-btn follow login-required" data-message=" You need to Sign up to follow a topic." data-trigger="follow_topic_btn" data-url="https://hackr.io/topics/software-design-patterns/follow"> <span class="button-title text-capitalize"><img class="img-white filter-white color-filter" src="https://hackr.io/assets/images/header-icons/add.svg" width="11"/> follow </span><span  ...
# <!-- Page Section Body -->
# <div class="page--section-body tutorial--tut-list">
# <div class="container alt">
# <div class="row">
# <div class="col-xs-12 container-top-tut no-paddingleft no-paddingright">
# <div class="row tag-selection hidden"> <div class="col-xs-12"> <div class="selected-tags--container"> <div class="col-xs-5 col-sm-3 col-md-2 no-padding"> <div class="selections-sec"> <p class="txt-bold">Your filter selection:</p> </div> </div> <div class="col-xs-7 col-sm-9 col-md-10 no-padding-mob"> <div class="selected-tags"> </div> </div> </div> </div> </div> <div class="flex-container"> <div class="sidebar-content tutorial-filters col-md-3 no-paddingleft"> <div class="sidebar-wrapper"> <div class="js-desktop-filters"> <div class="panel intro-panel panel-primary hidden-xs hidden-sm panel-tutorial-filters"> <div class="panel-header"> <div class="panel-heading"> <h3 class="text-capitalize">filter courses</h3> </div> </div> <div class="js-filters-content"> <div class="gooey-loader"> <span class="dot"></span> <div class="dots"> <span></span> <span></span> <span></span> </div> </div> </div> </div> </div> <div id="js-ziprecruiter-jobs"></div> <div style="margin-bottom: 15px;">
# <div id="gpt-passback">
# <div class="js-lazy-ad" data-src="window.googletag = window.googletag || {cmd: []};
#        googletag.cmd.push(function() {
#          googletag
#            .defineSlot('/147246189/hackr.io_300x250_left_tutorial_1_DFP', [300, 250], 'gpt-passback')
#            .addService(googletag.pubads());
#          googletag.enableServices();
#          googletag.display('gpt-passback');
#      });">
# </div>
# </div>
# </div> </div> </div> <div class="main--content col-xs-12 col-sm-12 col-md-9 no-paddingright no-paddingleft"> <div class="js-tutorial-listing-content"> <div class="main-content border"> <div class="top-tut-container"> <p class="top-tut-title">Top Design Patterns tutorials</p> <div class="top-tut-filters hidden-xs hidden-sm"> <button class="text-capitalize top-tut-selection selection-active js-sort-btn" data-sort="upvotes" title="Sort tutorial from highest to lowest upvotes"> upvotes<span class="sort-arrow"> <img class="sort-img" height="10" src="https://hackr.io/assets/images/header-icons/upvote-filter-arrow.svg"/> </span> </button> <span class="separator">|</span> <button class="text-capitalize top-tut-selection js-sort-btn" data-sort="recent" title="Sort tutorials by most recently submitted to oldest"> recent<span class="sort-arrow"> <img class="sort-img" height="10" src="https://hackr.io/assets/images/header-icons/upvote-filter-arrow.svg"/> </span> </button> </div> <div class="top-tut-filters--mobile visible-xs visible-sm"><a class="cta-tut-filter text-capitalize" href="#">filters &gt;&gt;</a></div> </div> <div class="tutorial-listing-wrapper"> <div class="tutorial-listing"> <div class="tut-list tut-list-new tut-row"> <div class="tut-list-primary"> <div class="tut-vote"> <a class="vote-widget login-required" data-id="14341" data-message="  You need to Sign up to upvote" data-topic="Design Patterns" data-trigger="upvote_tutuorial_btn" data-url="https://hackr.io/tutorial/design-patterns-ruby/vote" href="javascript:void(0)"> <span class="arrow"> <img class="arrow-img gray" src="https://hackr.io/assets/images/header-icons/caret-up.svg"/> </span> <span class="count">1</span> <span class="tut-upvotes-text hidden">Upvote</span> </a> </div> <div class="tut-title with-tags"> <div class="title"> <div class="title-links no-margin"> <div class="title-tags"> <div class="label label-new" data-container="body" data-content="This tutorial was recently submitted to Hackr.io" data-placement="bottom" data-toggle="popover" data-trigger="hover" style="cursor: initial;" tabindex="0"> <i class="ion-ios-medical"></i> <span class="txt text-capitalize"> recent</span> </div> </div> <a class="js-tutorial-title marginright-sm" data-tutorialid="14341" data-tutorialrank="7" href="http://coursegalaxy.com/design-patterns/ruby.html" rel="nofollow" target="_blank"> <span class="tutorial-title-txt">Design Patterns In Ruby</span> <span class="tut-title-link"> <span class="js-tutorial" data-id="14341" target="_blank" title="Design Patterns In Ruby">(coursegalaxy.com)</span> </span> </a> </div> </div> <div class="action-footer"> <div class="left"> <div class="tut-footer-actions"> <form action="https://hackr.io/tutorial/design-patterns-ruby/save" class="save-tutorial-form" method="post"> <input name="_token" type="hidden" value="J7sct78WY26juyvCCd8HE3TjDYKRH3GFD9x0D9J5"/> <button class="bookmark-btn js-bookmark-btn paddingright-sm no-paddingleft no-paddingbottom fx fx--ai-c login-required" data-message="You need to signup to save a tutorial" data-trigger="bookmark_btn" type="submit"> <img class="bookmark-icon js-bookmark-icon" height="12" src="https://hackr.io/assets/images/header-icons/bookmark-gray.svg"/> <span class="bookmark-txt js-bookmark-text text-capitalize">bookmark</span> </button> </form> <div class="action author">Submitted by  <a class="author no-marginright paddingleft-xs" href="https://hackr.io/suresh-srivastava">Suresh</a> <span class="separator-footer"></span>  579 views   <span class="separator-footer"></span> <a class="btn comments-link js-comments-link" href="https://hackr.io/tutorial/design-patterns-ruby" target="_blank"> <span class="txt text-capitalize"> discuss</span> </a> </div> </div> <div class="tut-label-group marginright-sm"> <span class="tag-tooltip tag-select label label-xs label-primary" data-content="This is a free tutorial" data-id="t-1" data-placement="top" data-toggle="popover" data-trigger="manual" style="cursor: initial;" tabi ...
# <div id="gpt-passback-stpd-1-1572966252313">
# <div class="js-lazy-ad" data-src="window.googletag = window.googletag || {cmd: []};
#        googletag.cmd.push(function() {
#          googletag
#            .defineSlot('/147246189/hackr.io_800x336_topic_bottom_DFP', [[300, 250], [728, 90]], 'gpt-passback-stpd-1-1572966252313')
#            .addService(googletag.pubads());
#          googletag.enableServices();
#          googletag.display('gpt-passback-stpd-1-1572966252313');
#      });">
# </div>
# </div>
# </div> </div> </div> </div> </div>
# </div>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="appstore-links">
# </div>
# </div>
# <div class="share-footer share">
# <a class="fab no share-facebook js-share-facebook" data-shareurl="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fhackr.io%2Ftutorials%2Flearn-software-design-patterns" data-social="Facebook"></a>
# <a class="fab no share-twitter" data-social="Twitter" href="https://twitter.com/home?status=The+best+online+Design+Patterns+courses+%26+tutorials+recommended+by+the+programming+community.++https%3A%2F%2Fhackr.io%2Ftutorials%2Flearn-software-design-patterns" rel="noopener" target="_blank"></a>
# <a class="fab no share-whatsapp" data-social="WhatsApp" href="https://api.whatsapp.com/send?text=https%3A%2F%2Fhackr.io%2Ftutorials%2Flearn-software-design-patterns" rel="noopener" target="_blank"></a>
# <a class="fab no share-linkedin" data-social="LinkedIn" href=" https://www.linkedin.com/shareArticle?mini=true&amp;url=https://hackr.io/tutorials/learn-software-design-patterns" rel="noopener" target="_blank"></a>
# <a class="fab no share-reddit" data-social="Reddit" href="http://www.reddit.com/submit?url=https://hackr.io/tutorials/learn-software-design-patterns" rel="noopener" target="_blank"></a>
# <a class="hn-button fab no share-hackrnews" data-social="HackerNews" href="https://news.ycombinator.com/submitlink?u=https://hackr.io/tutorials/learn-software-design-patterns" rel="noopener" target="_blank"></a>
# </div>
# <!-- /.page-wrapper -->
# <script type="application/ld+json">
#     {
#       "@context":"http://schema.org",
#       "@type":"ItemList",
#       "itemListElement":[
#                         {
#           "@type":"ListItem",
#           "position": 1,
#           "url": "https://hackr.io/tutorial/design-patters-in-object-oriented-programming"
#         },                {
#           "@type":"ListItem",
#           "position": 2,
#           "url": "https://hackr.io/tutorial/design-patterns-tutorial"
#         },                {
#           "@type":"ListItem",
#           "position": 3,
#           "url": "https://hackr.io/tutorial/design-patterns"
#         },                {
#           "@type":"ListItem",
#           "position": 4,
#           "url": "https://hackr.io/tutorial/design-patterns-stories"
#         },                {
#           "@type":"ListItem",
#           "position": 5,
#           "url": "https://hackr.io/tutorial/wishlist-design-patterns-in-c-and-net"
#         },                {
#           "@type":"ListItem",
#           "position": 6,
#           "url": "https://hackr.io/tutorial/head-first-design-patterns-a-brain-friendly-guide"
#         },                {
#           "@type":"ListItem",
#           "position": 7,
#           "url": "https://hackr.io/tutorial/design-patterns-archives-vishal-chovatiya"
#         },                {
#           "@type":"ListItem",
#           "position": 8,
#           "url": "https://hackr.io/tutorial/secure-by-design"
#         },                {
#           "@type":"ListItem",
#           "position": 9,
#           "url": "https://hackr.io/tutorial/design-patterns-video-tutorial"
#         },                {
#           "@type":"ListItem",
#           "position": 10,
#           "url": "https://hackr.io/tutorial/design-patterns-php"
#         }              ]
#     }
#   </script>
# <script>
#     var topic_url = 'https://hackr.io/tutorials/learn-software-design-patterns';
#     var topic_blog_tag_id = '';
#     var topic_name = 'Design Patterns';
#   </script>
# <div aria-hidden="false" class="modal full-page-modal new-modal signup-modal" id="modalSignIn" role="dialog" tabindex="-1"> <div class="modal-container"> <button class="modal-action-btn action-right close-modal" data-dismiss="modal" type="button"><i class="ion-ios-close"></i></button> <div class="modal-dialog" role="document"> <div class="modal-content text-center"> <div class="modal-body new-modal-body signup-modal-body no-padding"> <div class="right-sec"> <div class="modal-header"> <div class="modal-title">Welcome Back</div> <div class="login-needed-alert"></div> <div class="modal-subtitle text-caps">Continue with:</div> </div> <div class="social-login-buttons fx fx--fd-c"> <div class="login-buttons"> <a class="btn_gplus" href="https://hackr.io/users/login/google" type="button"> <img height="50px" src="https://hackr.io/assets/images/google-signin-dark.png"/> </a> </div> <div class="second-row fx"> <div class="login-buttons"> <a class="btn btn-large btn_facebook" href="https://hackr.io/users/login/facebook" rel="nofollow"> <i class="ion-logo-facebook"></i> <span class="logo-text">Facebook</span> </a> </div> <div class="login-buttons"> <a class="btn btn-large btn_github" href="https://hackr.io/users/login/github" rel="nofollow"> <i class="ion-logo-github"></i> <span class="logo-text">Github</span> </a> </div> </div> </div> <div class="divider-with-text"><span class="divider-text text-uppercase">or</span></div> <form action="https://hackr.io/users/login/email" class="form-new" id="login-modal-form" method="post" name="userLoginForm"> <input name="_token" type="hidden" value="J7sct78WY26juyvCCd8HE3TjDYKRH3GFD9x0D9J5"/> <div class="form-group email-form-group"> <div class="input-with-icon"> <input class="form-control" name="email" placeholder="Email" type="email"/> <i class="input-icon ion-ios-mail"></i> </div> </div> <div class="form-group password-form-group"> <div class="input-with-icon"> <input autocomplete="off" class="form-control" name="password" placeholder="Password" type="password"/> <i class="input-icon ion-ios-lock"></i> </div> </div> <div class="form-group info g-recaptcha-response-form-group"> <div class="g-recaptcha" data-sitekey="6LcoNw8UAAAAAM524ycW66u7m4XKyWTcFnIKHlnQ"></div> </div> <div class="form-group form-actions"> <a class="helper-text show-forgot-password" href="javascript:void(0);">Forgot Password</a> </div> <div class="form-group submit-form-group"> <button class="btn full_width spinning-loader btn-large" type="submit"><span class="txt">Login</span><i class="ion-ios-radio-button-off fa-spin"></i></button> </div> </form> <p class="para no-margin">Don't have an account? <a class="open-signup-modal login-text" href="javascript:void(0);">Sign Up</a></p> </div> </div> </div> </div> </div> </div> <div aria-hidden="false" class="modal full-page-modal new-modal signup-modal" id="modalSignUp" role="dialog" tabindex="-1"> <div class="modal-container"> <button class="modal-action-btn action-right close-modal" data-dismiss="modal" type="button"><i class="ion-ios-close"></i></button> <div class="modal-dialog" role="document"> <div class="modal-content text-center"> <div class="modal-body new-modal-body signup-modal-body no-padding"> <div class="right-sec"> <div class="modal-header"> <div class="modal-title">Welcome to Hackr.io</div> <div class="modal-subtitle">Signup to submit and upvote tutorials, follow topics, and more.</div> <div class="login-needed-alert"></div> <div class="modal-subtitle text-caps">Continue with:</div> </div> <div class="social-login-buttons fx fx--fd-c"> <div class="login-buttons"> <a class="btn_gplus" href="https://hackr.io/users/login/google" type="button"> <img height="50px" src="https://hackr.io/assets/images/google-signin-dark.png"/> </a> </div> <div class="second-row fx"> <div class="login-buttons"> <a class="btn btn-large btn_facebook" href="https://hackr.io/users/login/facebook"> <i class="ion-logo-facebook"></i> <span class="logo-text">Facebook</span> </a> </div> <div class="login-bu ...
# <script type="text/javascript">
#     /* Second CSS File */
#     var thirdPartyCss = document.createElement('link');
#     thirdPartyCss.rel = 'stylesheet';
#     thirdPartyCss.href = "https://hackr.io/dist/third-party-05517d5929074b7c0d24.css";
#     thirdPartyCss.type = 'text/css';
#     var godefer = document.getElementsByTagName('link')[0];
#     godefer.parentNode.insertBefore(thirdPartyCss, godefer);
#   </script>
# <script type="text/javascript">
#     /* Second CSS File */
#     var additionalCssLink = document.createElement('link');
#     additionalCssLink.rel = 'stylesheet';
#     additionalCssLink.href = "https://hackr.io/dist/additional-05517d5929074b7c0d24.css";
#     additionalCssLink.type = 'text/css';
#     var godefer = document.getElementsByTagName('link')[0];
#     godefer.parentNode.insertBefore(additionalCssLink, godefer);
#   </script>
# <script src="https://hackr.io/assets/js/lang.dist.js"></script>
# <script type="text/javascript">
#     var site = 'programming';
#     var site_id = 1;
#     var audience = 'programmers';
#     var sites = {
#       1: "Programming",
#       2: "Design"
#     }
#     var base_url = "https://hackr.io/".replace(/\/$/, "");
#     var asset_path = "https://hackr.io/assets";
#     var cdn_base_url = "https://hackr.io/".replace(/\/$/, "");
#     var vapid_public_key = ""
#         var user_id = ""
#     var currencyConversion = [];
#     var currencyLogos = [];
#     var googleClientId = "";
#     Lang.setLocale('en');
# </script>
# <script type="text/javascript">
#   function downloadJSAtOnload() {
#   var element = document.createElement("script");
#   element.src = "https://hackr.io/dist/app-05517d5929074b7c0d24.js";
#   document.body.appendChild(element);
#   }
#   if (window.addEventListener)
#   window.addEventListener("load", downloadJSAtOnload, false);
#   else if (window.attachEvent)
#   window.attachEvent("onload", downloadJSAtOnload);
#   else window.onload = downloadJSAtOnload;
# </script>
# <script async="" defer="" src="https://www.google.com/recaptcha/api.js"></script> </body>
# </html>

# %%
result = soup.find(id='resultsCol')
result

# %%
courses = soup.find_all('div', class_ ="tut-list tut-list-new tut-row")
print(type(courses))
print(len(courses))
# Out:
# <class 'bs4.element.ResultSet'>
# 11

# %% [markdown]
# Now we’ll select only the first container, and extract, by turn, each item of interest:
#
# - Course title
# - Votes
# - Link
# - Free / Paid
# - Course type

# %%
first_course = courses[0]
first_course
# Out:
# <div class="tut-list tut-list-new tut-row"> <div class="tut-list-primary"> <div class="tut-vote"> <a class="vote-widget login-required" data-id="14341" data-message="  You need to Sign up to upvote" data-topic="Design Patterns" data-trigger="upvote_tutuorial_btn" data-url="https://hackr.io/tutorial/design-patterns-ruby/vote" href="javascript:void(0)"> <span class="arrow"> <img class="arrow-img gray" src="https://hackr.io/assets/images/header-icons/caret-up.svg"/> </span> <span class="count">1</span> <span class="tut-upvotes-text hidden">Upvote</span> </a> </div> <div class="tut-title with-tags"> <div class="title"> <div class="title-links no-margin"> <div class="title-tags"> <div class="label label-new" data-container="body" data-content="This tutorial was recently submitted to Hackr.io" data-placement="bottom" data-toggle="popover" data-trigger="hover" style="cursor: initial;" tabindex="0"> <i class="ion-ios-medical"></i> <span class="txt text-capitalize"> recent</span> </div> </div> <a class="js-tutorial-title marginright-sm" data-tutorialid="14341" data-tutorialrank="7" href="http://coursegalaxy.com/design-patterns/ruby.html" rel="nofollow" target="_blank"> <span class="tutorial-title-txt">Design Patterns In Ruby</span> <span class="tut-title-link"> <span class="js-tutorial" data-id="14341" target="_blank" title="Design Patterns In Ruby">(coursegalaxy.com)</span> </span> </a> </div> </div> <div class="action-footer"> <div class="left"> <div class="tut-footer-actions"> <form action="https://hackr.io/tutorial/design-patterns-ruby/save" class="save-tutorial-form" method="post"> <input name="_token" type="hidden" value="J7sct78WY26juyvCCd8HE3TjDYKRH3GFD9x0D9J5"/> <button class="bookmark-btn js-bookmark-btn paddingright-sm no-paddingleft no-paddingbottom fx fx--ai-c login-required" data-message="You need to signup to save a tutorial" data-trigger="bookmark_btn" type="submit"> <img class="bookmark-icon js-bookmark-icon" height="12" src="https://hackr.io/assets/images/header-icons/bookmark-gray.svg"/> <span class="bookmark-txt js-bookmark-text text-capitalize">bookmark</span> </button> </form> <div class="action author">Submitted by  <a class="author no-marginright paddingleft-xs" href="https://hackr.io/suresh-srivastava">Suresh</a> <span class="separator-footer"></span>  579 views   <span class="separator-footer"></span> <a class="btn comments-link js-comments-link" href="https://hackr.io/tutorial/design-patterns-ruby" target="_blank"> <span class="txt text-capitalize"> discuss</span> </a> </div> </div> <div class="tut-label-group marginright-sm"> <span class="tag-tooltip tag-select label label-xs label-primary" data-content="This is a free tutorial" data-id="t-1" data-placement="top" data-toggle="popover" data-trigger="manual" style="cursor: initial;" tabindex="0"> Free </span> <span class="tag-tooltip tag-select label label-xs label-primary" data-content="This tutorial is suitable for beginners" data-id="t-7" data-placement="top" data-toggle="popover" data-trigger="manual" style="cursor: initial;" tabindex="0"> Beginner </span> <span class="tag-tooltip tag-select label label-xs label-primary" data-id="s-14">Ruby</span> </div> </div> <div class="right"> <div class="show-oneLiners action details"> <a class="js-granular-details show-granular-details" data-loaded="false" data-topic="Design Patterns" data-tutorial="Design Patterns In Ruby" data-url="https://hackr.io/tutorial/design-patterns-ruby/granulars" href="javascript:void(0);"> <img class="js-details-icon tut-footer-action-chevron arrow-icon" src="https://hackr.io/assets/images/header-icons/caret-down.svg"/> </a> </div> </div> </div> </div> </div> <div class="tut-list-secondary"> <div class="js-granular-container"> </div> </div> </div>

# %%
course_title  = first_course.div.find('span', class_ = 'tutorial-title-txt')
course_title.text.strip()
# Out:
# 'Design Patterns In Ruby'

# %%
vote=first_course.a.text
vote.strip()
# Out:
# '1 Upvote'

# %%
links  = first_course.find_all("a")
for link in links:
    print (link.get("href"))
# Out:
# javascript:void(0)
# http://coursegalaxy.com/design-patterns/ruby.html
# https://hackr.io/suresh-srivastava
# https://hackr.io/tutorial/design-patterns-ruby
# javascript:void(0);

# %%
types  = first_course.find_all('span', class_ = "tag-tooltip tag-select label label-xs label-primary")
for ty in types:
    print (ty.text.strip())
# Out:
# Free
# Beginner
# Ruby

# %% [markdown]
# features  = first_course.find('span', class_ = 'tag-tooltip tag-select label label-xs label-primary')
# features.text.strip()

# %% [markdown]
# class="tutorial-title-txt"

# %% [markdown]
# company  = first_job.div.find('span', class_ = 'company')
# company.text.strip()

# %% [markdown]
# location = first_job.find('span', class_ = "location")
# location.text.strip()

# %% [markdown]
# ratings  = first_job.find('span', class_ = 'ratingsContent')
# ratings.text.strip()

# %% [markdown]
# summary  = first_job.find('div', class_ = 'summary')
# summary.text.strip()

# %% [markdown]
# Repeat process for second job to test

# %%
second_course = courses[1]
second_course
# Out:
# <div class="tut-list tut-list-new tut-row"> <div class="tut-list-primary"> <div class="tut-vote"> <a class="vote-widget login-required" data-id="4892" data-message="  You need to Sign up to upvote" data-topic="Design Patterns" data-trigger="upvote_tutuorial_btn" data-url="https://hackr.io/tutorial/design-patters-in-object-oriented-programming/vote" href="javascript:void(0)"> <span class="arrow"> <img class="arrow-img gray" src="https://hackr.io/assets/images/header-icons/caret-up.svg"/> </span> <span class="count">16</span> <span class="tut-upvotes-text hidden">Upvotes</span> </a> </div> <div class="tut-title"> <div class="title"> <div class="title-links no-margin"> <a class="js-tutorial-title marginright-sm" data-tutorialid="4892" data-tutorialrank="1" href="https://www.youtube.com/playlist?list=PLrhzvIcii6GNjpARdnO4ueTUAVR9eMBpc" rel="nofollow" target="_blank"> <span class="tutorial-title-txt">Design Patters in Object Oriented Programming</span> <span class="tut-title-link"> <span data-id="4892" title="Design Patters in Object Oriented Programming">(youtube.com)</span> </span> </a> </div> </div> <div class="action-footer"> <div class="left"> <div class="tut-footer-actions"> <form action="https://hackr.io/tutorial/design-patters-in-object-oriented-programming/save" class="save-tutorial-form" method="post"> <input name="_token" type="hidden" value="J7sct78WY26juyvCCd8HE3TjDYKRH3GFD9x0D9J5"/> <button class="bookmark-btn js-bookmark-btn paddingright-sm no-paddingleft no-paddingbottom fx fx--ai-c login-required" data-message="You need to signup to save a tutorial" data-trigger="bookmark_btn" type="submit"> <img class="bookmark-icon js-bookmark-icon" height="12" src="https://hackr.io/assets/images/header-icons/bookmark-gray.svg"/> <span class="bookmark-txt js-bookmark-text text-capitalize">bookmark</span> </button> </form> <div class="action author">Submitted by  <a class="author no-marginright paddingleft-xs" href="https://hackr.io/egor-kalinin">Egor</a> <span class="separator-footer"></span>  6.9k+ views   <span class="separator-footer"></span> <a class="btn comments-link js-comments-link" href="https://hackr.io/tutorial/design-patters-in-object-oriented-programming" target="_blank"> <span class="txt text-capitalize">1 comment</span> </a> </div> </div> <div class="tut-label-group marginright-sm"> <span class="tag-tooltip tag-select label label-xs label-primary" data-content="This is a free tutorial" data-id="t-1" data-placement="top" data-toggle="popover" data-trigger="manual" style="cursor: initial;" tabindex="0"> Free </span> <span class="tag-tooltip tag-select label label-xs label-primary" data-content="Video-based tutorial" data-id="t-3" data-placement="top" data-toggle="popover" data-trigger="manual" style="cursor: initial;" tabindex="0"> Video </span> <span class="tag-tooltip tag-select label label-xs label-primary" data-content="This tutorial is suitable for beginners" data-id="t-7" data-placement="top" data-toggle="popover" data-trigger="manual" style="cursor: initial;" tabindex="0"> Beginner </span> </div> </div> <div class="right"> <div class="show-oneLiners action details"> <a class="js-granular-details show-granular-details" data-loaded="false" data-topic="Design Patterns" data-tutorial="Design Patters in Object Oriented Programming" data-url="https://hackr.io/tutorial/design-patters-in-object-oriented-programming/granulars" href="javascript:void(0);"> <img class="js-details-icon tut-footer-action-chevron arrow-icon" src="https://hackr.io/assets/images/header-icons/caret-down.svg"/> </a> </div> </div> </div> </div> </div> <div class="tut-list-secondary"> <div class="js-granular-container"> </div> </div> </div>

# %%
course_title  = second_course.div.find('span', class_ = 'tutorial-title-txt')
course_title.text.strip()
# Out:
# 'Design Patters in Object Oriented Programming'

# %%
vote=second_course.a.text
vote.strip()
# Out:
# '16 Upvotes'

# %%
import re
links  = second_course.find_all("a" , attrs={'href': re.compile("https://")})
#for link in links:
   # print (link.get("href"))
links[2].get("href")
#links[1].get("href")
#links
# Out:
# 'https://hackr.io/tutorial/design-patters-in-object-oriented-programming'

# %%
types  = second_course.find_all('span', class_ = "tag-tooltip tag-select label label-xs label-primary")
for ty in types:
    print (ty.text.strip())
# Out:
# Free
# Video
# Beginner

# %% [markdown]
# **The script for a single page**
#
# Before piecing together what we’ve done so far, we have to make sure that we’ll extract the data only from the jobs that have a rating. So we don't have incomplete data

# %%
# Lists to store the scraped data in
CourseTitles = []
NoOfVotes = []
CourseLinks = []
#AuthorLink = []
#HackrLink= []
CourseDetails = []


# Extract data from individual jobs
for course in courses:
# The CourseTitle
        CourseTitle = course.div.find('span', class_ = 'tutorial-title-txt').text.strip()
        CourseTitles.append(CourseTitle)
    # The NoOfVotes
        NoOfVote  = course.a.text.strip()
        NoOfVotes.append(NoOfVote)
    # The Links
        ref = course.find_all("a",attrs={'href': re.compile("https://")})
        for x in ref:
            Link = x.get("href") 
            while Link != "":
            CourseLinks.append(list(map(str,Link.split())))
    #i = input()
            #for y in Link:
           # link[]= 'Link \n\n'
       # Link2 = ref[1].get("href")
        #Link3 = ref[2].get("href")
                #CourseLinks.append(y) 
        #AuthorLink.append(Link2)
       # HackrLink.append(Link3)
    # The CourseDetails
        #dets  = course.find_all('span', class_ = "tag-tooltip tag-select label label-xs label-primary")
        #for ty in dets:
          #  CourseDetail  = ty.text.strip()
        #CourseDetails.append(CourseDetail)

# %%
CourseLinks
# Out:
# ['h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'h',
#  'a',
#  'c',
#  'k',
#  'r',
#  '.',
#  'i',
#  'o',
#  '/',
#  's',
#  'u',
#  'r',
#  'e',
#  's',
#  'h',
#  '-',
#  's',
#  'r',
#  'i',
#  'v',
#  'a',
#  's',
#  't',
#  'a',
#  'v',
#  'a',
#  '\n',
#  '\n',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'h',
#  'a',
#  'c',
#  'k',
#  'r',
#  '.',
#  'i',
#  'o',
#  '/',
#  't',
#  'u',
#  't',
#  'o',
#  'r',
#  'i',
#  'a',
#  'l',
#  '/',
#  'd',
#  'e',
#  's',
#  'i',
#  'g',
#  'n',
#  '-',
#  'p',
#  'a',
#  't',
#  't',
#  'e',
#  'r',
#  'n',
#  's',
#  '-',
#  'r',
#  'u',
#  'b',
#  'y',
#  '\n',
#  '\n',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'w',
#  'w',
#  'w',
#  '.',
#  'y',
#  'o',
#  'u',
#  't',
#  'u',
#  'b',
#  'e',
#  '.',
#  'c',
#  'o',
#  'm',
#  '/',
#  'p',
#  'l',
#  'a',
#  'y',
#  'l',
#  'i',
#  's',
#  't',
#  '?',
#  'l',
#  'i',
#  's',
#  't',
#  '=',
#  'P',
#  'L',
#  'r',
#  'h',
#  'z',
#  'v',
#  'I',
#  'c',
#  'i',
#  'i',
#  '6',
#  'G',
#  'N',
#  'j',
#  'p',
#  'A',
#  'R',
#  'd',
#  'n',
#  'O',
#  '4',
#  'u',
#  'e',
#  'T',
#  'U',
#  'A',
#  'V',
#  'R',
#  '9',
#  'e',
#  'M',
#  'B',
#  'p',
#  'c',
#  '\n',
#  '\n',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'h',
#  'a',
#  'c',
#  'k',
#  'r',
#  '.',
#  'i',
#  'o',
#  '/',
#  'e',
#  'g',
#  'o',
#  'r',
#  '-',
#  'k',
#  'a',
#  'l',
#  'i',
#  'n',
#  'i',
#  'n',
#  '\n',
#  '\n',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'h',
#  'a',
#  'c',
#  'k',
#  'r',
#  '.',
#  'i',
#  'o',
#  '/',
#  't',
#  'u',
#  't',
#  'o',
#  'r',
#  'i',
#  'a',
#  'l',
#  '/',
#  'd',
#  'e',
#  's',
#  'i',
#  'g',
#  'n',
#  '-',
#  'p',
#  'a',
#  't',
#  't',
#  'e',
#  'r',
#  's',
#  '-',
#  'i',
#  'n',
#  '-',
#  'o',
#  'b',
#  'j',
#  'e',
#  'c',
#  't',
#  '-',
#  'o',
#  'r',
#  'i',
#  'e',
#  'n',
#  't',
#  'e',
#  'd',
#  '-',
#  'p',
#  'r',
#  'o',
#  'g',
#  'r',
#  'a',
#  'm',
#  'm',
#  'i',
#  'n',
#  'g',
#  '\n',
#  '\n',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  's',
#  'o',
#  'u',
#  'r',
#  'c',
#  'e',
#  'm',
#  'a',
#  'k',
#  'i',
#  'n',
#  'g',
#  '.',
#  'c',
#  'o',
#  'm',
#  '/',
#  'd',
#  'e',
#  's',
#  'i',
#  'g',
#  'n',
#  '_',
#  'p',
#  'a',
#  't',
#  't',
#  'e',
#  'r',
#  'n',
#  's',
#  '\n',
#  '\n',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'h',
#  'a',
#  'c',
#  'k',
#  'r',
#  '.',
#  'i',
#  'o',
#  '/',
#  'm',
#  'a',
#  'r',
#  'c',
#  '-',
#  'a',
#  'n',
#  't',
#  'o',
#  'i',
#  'n',
#  'e',
#  '-',
#  'l',
#  'o',
#  'r',
#  't',
#  'i',
#  'e',
#  '\n',
#  '\n',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'h',
#  'a',
#  'c',
#  'k',
#  'r',
#  '.',
#  'i',
#  'o',
#  '/',
#  't',
#  'u',
#  't',
#  'o',
#  'r',
#  'i',
#  'a',
#  'l',
#  '/',
#  'd',
#  'e',
#  's',
#  'i',
#  'g',
#  'n',
#  '-',
#  'p',
#  'a',
#  't',
#  't',
#  'e',
#  'r',
#  'n',
#  's',
#  '-',
#  't',
#  'u',
#  't',
#  'o',
#  'r',
#  'i',
#  'a',
#  'l',
#  '\n',
#  '\n',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'r',
#  'e',
#  'f',
#  'a',
#  'c',
#  't',
#  'o',
#  'r',
#  'i',
#  'n',
#  'g',
#  '.',
#  'g',
#  'u',
#  'r',
#  'u',
#  '/',
#  'd',
#  'e',
#  's',
#  'i',
#  'g',
#  'n',
#  '-',
#  'p',
#  'a',
#  't',
#  't',
#  'e',
#  'r',
#  'n',
#  's',
#  '\n',
#  '\n',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'h',
#  'a',
#  'c',
#  'k',
#  'r',
#  '.',
#  'i',
#  'o',
#  '/',
#  'c',
#  'l',
#  'i',
#  'f',
#  'f',
#  'o',
#  'r',
#  'd',
#  'f',
#  'a',
#  'j',
#  'a',
#  'r',
#  'd',
#  'o',
#  '\n',
#  '\n',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'h',
#  'a',
#  'c',
#  'k',
#  'r',
#  '.',
#  'i',
#  'o',
#  '/',
#  't',
#  'u',
#  't',
#  'o',
#  'r',
#  'i',
#  'a',
#  'l',
#  '/',
#  'd',
#  'e',
#  's',
#  'i',
#  'g',
#  'n',
#  '-',
#  'p',
#  'a',
#  't',
#  't',
#  'e',
#  'r',
#  'n',
#  's',
#  '\n',
#  '\n',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'h',
#  'a',
#  'c',
#  'k',
#  'r',
#  '.',
#  'i',
#  'o',
#  '/',
#  'd',
#  's',
#  't',
#  'a',
#  'r',
#  '5',
#  '5',
#  '\n',
#  '\n',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'h',
#  'a',
#  'c',
#  'k',
#  'r',
#  '.',
#  'i',
#  'o',
#  '/',
#  't',
#  'u',
#  't',
#  'o',
#  'r',
#  'i',
#  'a',
#  'l',
#  '/',
#  'd',
#  'e',
#  's',
#  'i',
#  'g',
#  'n',
#  '-',
#  'p',
#  'a',
#  't',
#  't',
#  'e',
#  'r',
#  'n',
#  's',
#  '-',
#  's',
#  't',
#  'o',
#  'r',
#  'i',
#  'e',
#  's',
#  '\n',
#  '\n',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'c',
#  'l',
#  'i',
#  'c',
#  'k',
#  '.',
#  'l',
#  'i',
#  'n',
#  'k',
#  's',
#  'y',
#  'n',
#  'e',
#  'r',
#  'g',
#  'y',
#  '.',
#  'c',
#  'o',
#  'm',
#  '/',
#  'd',
#  'e',
#  'e',
#  'p',
#  'l',
#  'i',
#  'n',
#  'k',
#  '?',
#  'i',
#  'd',
#  '=',
#  'j',
#  'U',
#  '7',
#  '9',
#  'Z',
#  'y',
#  's',
#  'i',
#  'h',
#  's',
#  '4',
#  '&',
#  'm',
#  'i',
#  'd',
#  '=',
#  '3',
#  '9',
#  '1',
#  '9',
#  '7',
#  '&',
#  'm',
#  'u',
#  'r',
#  'l',
#  '=',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'w',
#  'w',
#  'w',
#  '.',
#  'u',
#  'd',
#  'e',
#  'm',
#  'y',
#  '.',
#  'c',
#  'o',
#  'm',
#  '/',
#  'd',
#  'e',
#  's',
#  'i',
#  'g',
#  'n',
#  '-',
#  'p',
#  'a',
#  't',
#  't',
#  'e',
#  'r',
#  'n',
#  's',
#  '-',
#  'c',
#  's',
#  'h',
#  'a',
#  'r',
#  'p',
#  '-',
#  'd',
#  'o',
#  't',
#  'n',
#  'e',
#  't',
#  '/',
#  '\n',
#  '\n',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'h',
#  'a',
#  'c',
#  'k',
#  'r',
#  '.',
#  'i',
#  'o',
#  '/',
#  'd',
#  'a',
#  'n',
#  'i',
#  'e',
#  'l',
#  '-',
#  'l',
#  'e',
#  'e',
#  '\n',
#  '\n',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'h',
#  'a',
#  'c',
#  'k',
#  'r',
#  '.',
#  'i',
#  'o',
#  '/',
#  't',
#  'u',
#  't',
#  'o',
#  'r',
#  'i',
#  'a',
#  'l',
#  '/',
#  'w',
#  'i',
#  's',
#  'h',
#  'l',
#  'i',
#  's',
#  't',
#  '-',
#  'd',
#  'e',
#  's',
#  'i',
#  'g',
#  'n',
#  '-',
#  'p',
#  'a',
#  't',
#  't',
#  'e',
#  'r',
#  'n',
#  's',
#  '-',
#  'i',
#  'n',
#  '-',
#  'c',
#  '-',
#  'a',
#  'n',
#  'd',
#  '-',
#  'n',
#  'e',
#  't',
#  '\n',
#  '\n',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'g',
#  'e',
#  'n',
#  'i',
#  '.',
#  'u',
#  's',
#  '/',
#  'u',
#  'a',
#  'f',
#  '8',
#  '0',
#  '2',
#  'G',
#  '\n',
#  '\n',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'h',
#  'a',
#  'c',
#  'k',
#  'r',
#  '.',
#  'i',
#  'o',
#  '/',
#  'd',
#  'a',
#  'n',
#  'i',
#  'e',
#  'l',
#  '-',
#  'l',
#  'e',
#  'e',
#  '\n',
#  '\n',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'h',
#  'a',
#  'c',
#  'k',
#  'r',
#  '.',
#  'i',
#  'o',
#  '/',
#  't',
#  'u',
#  't',
#  'o',
#  'r',
#  'i',
#  'a',
#  'l',
#  '/',
#  'h',
#  'e',
#  'a',
#  'd',
#  '-',
#  'f',
#  'i',
#  'r',
#  's',
#  't',
#  '-',
#  'd',
#  'e',
#  's',
#  'i',
#  'g',
#  'n',
#  '-',
#  'p',
#  'a',
#  't',
#  't',
#  'e',
#  'r',
#  'n',
#  's',
#  '-',
#  'a',
#  '-',
#  'b',
#  'r',
#  'a',
#  'i',
#  'n',
#  '-',
#  'f',
#  'r',
#  'i',
#  'e',
#  'n',
#  'd',
#  'l',
#  'y',
#  '-',
#  'g',
#  'u',
#  'i',
#  'd',
#  'e',
#  '\n',
#  '\n',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'h',
#  'a',
#  'c',
#  'k',
#  'r',
#  '.',
#  'i',
#  'o',
#  '/',
#  'v',
#  'i',
#  's',
#  'h',
#  'a',
#  'l',
#  '-',
#  'c',
#  'h',
#  'o',
#  'v',
#  'a',
#  't',
#  'i',
#  'y',
#  'a',
#  '\n',
#  '\n',
#  'h',
#  't',
#  't',
#  'p',
#  's',
#  ':',
#  '/',
#  '/',
#  'h',
#  'a',
#  'c',
#  'k',
#  'r',
#  '.',
#  'i',
#  'o',
#  '/',
#  't',
#  'u',
#  't',
#  'o',
#  'r',
#  'i',
#  'a',
#  'l',
#  '/',
#  'd',
#  ...]

# %%
import pandas as pd
Design_df = pd.DataFrame({'Course': CourseTitles,
'Votes': NoOfVotes,
"Course Link":CourseLinks,
"Author Link": AuthorLink,
})
print(Design_df.info())
Design_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-831d75723e02> in <module>
#       1 import pandas as pd
# ----> 2 Design_df = pd.DataFrame({'Course': CourseTitles,
#       3 'Votes': NoOfVotes,
#       4 "Course Link":CourseLinks,
#       5 "Author Link": AuthorLink,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      76         # figure out the index, if necessary
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#      80             index = ensure_index(index)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     395             lengths = list(set(raw_lengths))
#     396             if len(lengths) > 1:
# --> 397                 raise ValueError("arrays must all be same length")
#     398
#     399             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
Design_df.to_csv('Design.csv')

# %% [markdown]
# **The script for multiple pages**
#
# We’ll build upon our one-page script by doing three more things:
#
# - Making all the requests we want from within the loop.
# - Controlling the loop’s rate to avoid bombarding the server with requests.
# - Monitoring the loop while it runs.

# %% [markdown]
# **How do the URLs change when you navigate to the next results page?**
#
# - page 1 = https://www.indeed.com/q-robotics-l-United-States-jobs.html
#
# - page 2 = https://www.indeed.com/jobs?q=robotics&l=United+States&start=10
#
# - page 3 = https://www.indeed.com/jobs?q=robotics&l=United+States&start=20
#
# - page 4 = https://www.indeed.com/jobs?q=robotics&l=United+States&start=30
